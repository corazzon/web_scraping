# %% [markdown]
# Request URL:
# https://mfront.homeplus.co.kr/review/getItemReview.json?groupItem=N&isAttached=false&itemNo=070882254&myStore=N&page=3&perPage=30&reviewFilter=&sort=reg&storeKind=NOR&storeType=HYPER&type=A
# Request Method:
# GET
# Status Code:
# 200 OK
# Remote Address:
# 52.79.144.93:443
# Referrer Policy:
# strict-origin-when-cross-origin

# %%
import requests
import pandas as pd

# URL 및 파라미터 설정
url = "https://mfront.homeplus.co.kr/review/getItemReview.json"
params = {
    "groupItem": "N",
    "isAttached": "false",
    "itemNo": "070882254",
    "myStore": "N",
    "page": 3,
    "perPage": 30,
    "reviewFilter": "",
    "sort": "reg",
    "storeKind": "NOR",
    "storeType": "HYPER",
    "type": "A"
}

# 데이터 요청
response = requests.get(url, params=params)
if response.status_code == 200:
    data = response.json()
    
    # 리뷰 데이터 추출
    reviews = data.get("data", [])
    
    # 데이터프레임 생성
    review_list = []
    for review in reviews:
        review_list.append({
            "Date": review.get("chgDt"),
            "Content": review.get("contents"),
            "Grade": review.get("grade"),
            "Grade Name": review.get("gradeNm"),
            "Images": [img["imgUrl"] for img in review.get("imageList", [])]
        })
    
    # 데이터프레임으로 변환
    df = pd.DataFrame(review_list)
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
df
# Out:
#                    Date                                            Content  \
# 0   2025-01-13 15:02:10                                      잘받았습니다 감사합니다
# 1   2025-01-13 14:38:45                                     잘받았습니다 잘먹겠습니다
# 2   2025-01-13 11:40:00                   리뷰에 맛나다길래 구매했어용\n맥주랑 먹으니 맛나네요~~
# 3   2025-01-13 11:09:59                               할인해서 저렴하게 구매했어요 좋아요
# 4   2025-01-13 07:11:35                                         ㅊㅂㅊㅂㅊㅊㅂㅊㅂㅂ
# 5   2025-01-12 23:23:36                       잘 받았습니다 추운데 집까지 배달해주셔서 감사합니다
# 6   2025-01-12 22:28:34                                               None
# 7   2025-01-12 22:19:49                                  맛있어요. 밥이랑  먹기 좋아요
# 8   2025-01-12 21:46:15                                        신제품이라서 구매해봄
# 9   2025-01-12 20:35:19         윙봉은 괜춘한데 다리에서 좀 냄새가 나요 소스는 진한 데리야키나 간장 비슷
# 10  2025-01-12 19:37:08                                               None
# 11  2025-01-12 19:05:38                                   생각보다 맛있어서 잘 먹었어요
# 12  2025-01-12 16:46:00                                               None
# 13  2025-01-12 16:22:26                                       좋아요 좋아요 좋아요
# 14  2025-01-12 15:41:08                         집에서도 편안하게 배송 받을수 있어 감사합니다
# 15  2025-01-12 14:56:06                 후라이드는  식으니  냄새나서  갈비맛 사서 시댁  들렸어요
# 16  2025-01-12 14:15:45                                               None
# 17  2025-01-12 12:54:34                      약간 매콤한 맛이 느껴지네요, 많이 먹기에는 느끼해요
# 18  2025-01-12 11:59:39
# 19  2025-01-12 00:34:34                                   집에서 치킨 편히 받아 좋아요
# 20  2025-01-12 00:19:58                                       맛있게 잘 먹었어요~~
# 21  2025-01-11 22:52:29                                 맛있고 저렴하고 또 구입해야겠어요
# 22  2025-01-11 21:36:00                                       잘받았습니다 감사합니다
# 23  2025-01-11 21:09:05  처음 먹었는데 국내산에 맛있는 부위로 시켜먹는 치킨보다 양도 많고 싸고 맛있어요 아...
# 24  2025-01-11 20:39:47                                     잘 받았습니다 감사합니다
# 25  2025-01-11 20:12:36                                     맛있네요 양많고 신선해요
# 26  2025-01-11 19:06:23                                     정말 맛있어요 추천합니다~
# 27  2025-01-11 18:33:58                                     잘받았습니다 잘먹겠습니다
# 28  2025-01-11 18:00:52  너무 저렴해 깜짝 놀라고, 국내산 닭이라 두번 놀랐어요!! \n다리5 윙5 봉5 들...
# 29  2025-01-11 17:40:36                               잘받았습니다 감사합니다 재구매입니다
#
#     Grade Grade Name                                             Images
# 0     5.0       VIP+         [/us/56592b35-8e81-4e21-8908-9d7ec1e7d3ae]
# 1     4.0       VIP+         [/us/0cfef5e8-ced9-4c6b-9dcc-a125f2fada5a]
# 2     4.0      Gold+         [/us/78136ce5-763c-4acb-8b43-d45a2c87da84]
# 3     5.0       VIP+         [/us/1c6227c8-b40e-4815-87ce-15b1ab74bb6d]
# 4     5.0       VIP+         [/us/3bfb2e62-5403-476b-a898-9a129b457c38]
# 5     5.0    Family+         [/us/d75ba106-f74a-4e83-8cb2-507e7d65c789]
# 6     4.0    Family+                                                 []
# 7     5.0       VIP+                                                 []
# 8     4.0    Silver+         [/us/d5675995-d07b-41f5-a4ce-0863f0ef74ec]
# 9     5.0       VIP+         [/us/0c5754a4-34ea-4cad-842d-cefc713de8db]
# 10    5.0    Silver+                                                 []
# 11    4.0      Gold+         [/us/0bec64e7-0263-40fc-912c-8334b347c553]
# 12    5.0    Family+                                                 []
# 13    5.0      Gold+                                                 []
# 14    4.0    Family+                                                 []
# 15    5.0       VIP+  [/us/849b3e5d-f344-402c-8ae8-e0eaa7f54cb2, /us...
# 16    5.0    Silver+                                                 []
# 17    4.0      Gold+         [/us/36343bdb-b28f-4f1e-9c0e-21d5c773bbf3]
# 18    4.0    Family+                                                 []
# 19    5.0    Family+                                                 []
# 20    5.0      Gold+         [/us/f1e4c09c-6751-418e-8ab0-9ca49ab4f52a]
# 21    5.0    Family+                                                 []
# 22    5.0    Silver+         [/us/dc098e7a-c616-4973-afe8-e7ac0eaba626]
# 23    5.0    Family+                                                 []
# 24    5.0       VIP+                                                 []
# 25    5.0    Family+         [/us/3cb7b7d7-fbdc-4266-ab3f-62a12e6a8fff]
# 26    5.0    Silver+                                                 []
# 27    4.0       VIP+         [/us/1fdac19b-95cd-490f-8913-64989d67525f]
# 28    5.0       VIP+  [/us/f00bee9f-91cb-4a8a-88a9-4fb42ba2816f, /us...
# 29    5.0       VIP+         [/us/980da7e4-b719-4a56-83e7-2748e0a74418]
