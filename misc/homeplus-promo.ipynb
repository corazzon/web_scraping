# %% [markdown]
# Request URL:
# https://mfront.homeplus.co.kr/promo.json?page=1&perPage=20&promoNo=13218&sort=NEW&themeNo=46056
# Request Method:
# GET
# Status Code:
# 200 OK
# Remote Address:
# 52.79.144.93:443
# Referrer Policy:
# strict-origin-when-cross-origin
#
# Payload 정보
#
# page=1&perPage=20&promoNo=13218&sort=NEW&themeNo=46056
#
# 다음은 응답의 일부
#
# {
#     "returnStatus": 200,
#     "data": {
#         "dataList": [
#             {
#                 "addCartType": "02",
#                 "adultType": "NORMAL",
#                 "brandNm": null,
#                 "dcPrice": null,
#                 "dcTooltip": null,
#                 "dcType": "DEFAULT_PRICE",
#                 "docId": "H070882254N37O0",
#                 "eventInfo": null,
#                 "grade": 4.6,
#                 "imgDispYn": "Y",
#                 "itemNm": "당당갈비왕치킨콤보",
#                 "itemNo": "070882254",
#                 "itemType": "N",
#                 "labelList": [],
#                 "lcateCd": 100016,
#                 "mcateCd": 200118,
#                 "scateCd": 300439,
#                 "dcateCd": 400643,
#                 "optNo": null,
#                 "priceSuffix": null,
#                 "purchaseLimitDay": null,
#                 "purchaseLimitDuration": "O",
#                 "purchaseLimitQty": 1,
#                 "purchaseLimitYn": "Y",
#                 "purchaseMinQty": 1,
#                 "relationItemCnt": null,
#                 "relationNo": null,
#                 "rentalFee": 0,
#                 "reviewCnt": 163,
#                 "salePrice": 11990,
#                 "saleUnit": 1,
#                 "salesCnt": 5377,
#                 "searchTagList": [],
#                 "sellerCatalog": null,
#                 "sellerInfo": null,
#                 "shipMethod": "TD_DRCT",
#                 "soldOutYn": "N",
#                 "stickerEvent": null,
#                 "stickerItem": null,
#                 "storeId": 37,
#                 "storeKind": "NOR",
#                 "storeType": "HYPER",
#                 "todayShipLabel": null,
#                 "totalUnitQty": 0.0,
#                 "unitDispYn": "N",
#                 "unitMeasure": "개",
#                 "unitQty": null,
#                 "videoYn": "N",
#                 "singlePrice": 11990,
#                 "recomMsg": null,
#                 "stickerEventList": [],
#                 "benefitLabelList": [],
#                 "basicLabelList": [],
#                 "dcRate": null,
#                 "rsvInfo": null,
#                 "docDispYn": "Y",
#                 "rsvDocDispYn": "N",
#                 "pickupYn": "Y",
#                 "pickupOnlyItemYn": "N",
#                 "rsvSoldOutYn": "N",
#                 "itemShipMethod": "TD_DRCT",
#                 "itemShipMethodNm": "마트직송",
#                 "itemShipMethodFlag": "TD_DRCT",
#                 "itemSoldOutYn": "N",
#                 "itemQty": 1,
#                 "unitPrice": null,
#                 "frontDcRate": "",
#                 "pickupDispYn": "N",
#                 "udaInfo": null,
#                 "attrViewYn": "N",
#                 "itemAttrTop": null,
#                 "itemAttrBottom": null,
#                 "recentlyItemYn": "N",
#                 "rsvRemainCnt": 9999,
#                 "remainCnt": 8,
#                 "cartKindOfItem": "NOR",
#                 "rsvCartKindOfItem": "",
#                 "lcateNm": "델리/치킨/초밥",
#                 "mcateNm": "치킨/튀김/구이",
#                 "scateNm": "후라이드/양념/로스트",
#                 "dcateNm": "후라이드",
#                 "imgChgDt": "20241224111106"
#             },
#             {
#                 "addCartType": "02",
#                 "adultType": "NORMAL",
#
#
# 위 웹페이지의 데이터를 수집해서 판다스 데이터프레임으로 출력할 것

# %%
import requests
import pandas as pd

# API 요청
url = "https://mfront.homeplus.co.kr/promo.json?page=1&perPage=20&promoNo=13218&sort=NEW&themeNo=46056"
response = requests.get(url)
data = response.json()

# JSON 데이터에서 필요한 부분 추출
data_list = data['data']['dataList']

# 데이터프레임으로 변환
df = pd.DataFrame(data_list)

# 데이터프레임 출력
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.hist(figsize=(20, 20));
