# %% [markdown]
# https://www.inflearn.com/courses/client/api/v1/course/search?isDiscounted=false&isNew=false&pageNumber=3&pageSize=60&types=ONLINE

# %%
import requests
import sqlite3
import time
from datetime import datetime

today = datetime.today().strftime("%Y-%m-%d")
db_file = f'inflearn_courses-{today}.db'
db_file
# Out:
# 'inflearn_courses-2024-07-01.db'

# %%
def create_database():
    conn = sqlite3.connect(db_file)
    c = conn.cursor()
    c.execute('''CREATE TABLE IF NOT EXISTS courses
                 (id INTEGER PRIMARY KEY, 
                 title TEXT, 
                 instructor TEXT, 
                 price INTEGER, 
                 regular_price INTEGER, 
                 discount_rate REAL,
                 student_count INTEGER, 
                 review_count INTEGER, 
                 rating REAL,
                 last_updated TEXT)''')
    conn.commit()
    return conn

def fetch_courses(page_number, page_size=60):
    url = f"https://www.inflearn.com/courses/client/api/v1/course/search"
    params = {
        "isDiscounted": "false",
        "isNew": "false",
        "pageNumber": page_number,
        "pageSize": page_size,
        "types": "ONLINE"
    }
    response = requests.get(url, params=params)
    return response.json()

# %%
data = fetch_courses(page_number=1, page_size=60)
# data["data"]["items"][0]["instructor"]["name"]
course_inst = data["data"]["items"][0]

course = course_inst["course"]
instructor = course_inst["instructor"]
print(course.get('id'),
       course.get('title'),
       instructor.get('name'),
       course.get('price'),
       'regularPrice : ', course.get('regularPrice'),
       course.get('discountRate'),
       course.get('studentCount'),
       course.get('reviewCount'),
       course.get('star'),
       datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 332188 토비의 스프링 6 - 이해와 원리 토비 None regularPrice :  None None 716 11 5.0 2024-07-01 09:52:52

# %%
def scrape_inflearn():
    conn = create_database()
    c = conn.cursor()

    page_number = 1
    total_courses = 0

    while True:
        data = fetch_courses(page_number)
        courses = data["data"].get('items', [])

        if not courses:
            break

        for course_inst in courses:
            course = course_inst["course"]
            instructor = course_inst["instructor"]
            
            c.execute('''INSERT OR REPLACE INTO courses VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''',
                      (course.get('id'),
                       course.get('title'),
                       instructor.get('name'),
                       course.get('price'),
                       course.get('regularPrice'),
                       course.get('discountRate'),
                       course.get('studentCount'),
                       course.get('reviewCount'),
                       course.get('star'),
                       datetime.now().strftime('%Y-%m-%d %H:%M:%S')))

        conn.commit()
        total_courses += len(courses)
        print(f"Collected {len(courses)} courses from page {page_number}. Total: {total_courses}")

        page_number += 1
        time.sleep(1)  # 서버에 부담을 주지 않기 위한 딜레이

    conn.close()
    print(f"Scraping completed. Total courses collected: {total_courses}")

if __name__ == '__main__':
    scrape_inflearn()
# Out:
# Collected 60 courses from page 1. Total: 60
# Collected 60 courses from page 2. Total: 120
# Collected 60 courses from page 3. Total: 180
# Collected 60 courses from page 4. Total: 240
# Collected 60 courses from page 5. Total: 300
# Collected 60 courses from page 6. Total: 360
# Collected 60 courses from page 7. Total: 420
# Collected 60 courses from page 8. Total: 480
# Collected 60 courses from page 9. Total: 540
# Collected 60 courses from page 10. Total: 600
# Collected 60 courses from page 11. Total: 660
# Collected 60 courses from page 12. Total: 720
# Collected 60 courses from page 13. Total: 780
# Collected 60 courses from page 14. Total: 840
# Collected 60 courses from page 15. Total: 900
# Collected 60 courses from page 16. Total: 960
# Collected 60 courses from page 17. Total: 1020
# Collected 60 courses from page 18. Total: 1080
# Collected 60 courses from page 19. Total: 1140
# Collected 60 courses from page 20. Total: 1200
# Collected 60 courses from page 21. Total: 1260
# Collected 60 courses from page 22. Total: 1320
# Collected 60 courses from page 23. Total: 1380
# Collected 60 courses from page 24. Total: 1440
# Collected 60 courses from page 25. Total: 1500
# Collected 60 courses from page 26. Total: 1560
# Collected 60 courses from page 27. Total: 1620
# Collected 60 courses from page 28. Total: 1680
# Collected 60 courses from page 29. Total: 1740
# Collected 60 courses from page 30. Total: 1800
# Collected 60 courses from page 31. Total: 1860
# Collected 60 courses from page 32. Total: 1920
# Collected 60 courses from page 33. Total: 1980
# Collected 60 courses from page 34. Total: 2040
# Collected 60 courses from page 35. Total: 2100
# Collected 60 courses from page 36. Total: 2160
# Collected 60 courses from page 37. Total: 2220
# Collected 60 courses from page 38. Total: 2280
# Collected 60 courses from page 39. Total: 2340
# Collected 60 courses from page 40. Total: 2400
# Collected 60 courses from page 41. Total: 2460
# Collected 60 courses from page 42. Total: 2520
# Collected 60 courses from page 43. Total: 2580
# Collected 60 courses from page 44. Total: 2640
# Collected 60 courses from page 45. Total: 2700
# Collected 60 courses from page 46. Total: 2760
# Collected 60 courses from page 47. Total: 2820
# Collected 60 courses from page 48. Total: 2880
# Collected 60 courses from page 49. Total: 2940
# Collected 60 courses from page 50. Total: 3000
# Collected 60 courses from page 51. Total: 3060
# Collected 60 courses from page 52. Total: 3120
# Collected 60 courses from page 53. Total: 3180
# Collected 60 courses from page 54. Total: 3240
# Collected 60 courses from page 55. Total: 3300
# Collected 60 courses from page 56. Total: 3360
# Collected 60 courses from page 57. Total: 3420
# Collected 37 courses from page 58. Total: 3457
# Scraping completed. Total courses collected: 3457

# %%
def test_database():
    # 데이터베이스 연결
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    # 총 레코드 수 확인
    cursor.execute("SELECT COUNT(*) FROM courses")
    total_records = cursor.fetchone()[0]
    print(f"총 레코드 수: {total_records}")

    # 무작위로 5개 레코드 출력 (5개 미만이면 전체 출력)
    sample_size = min(5, total_records)
    cursor.execute(f"SELECT * FROM courses ORDER BY RANDOM() LIMIT {sample_size}")
    sample_records = cursor.fetchall()
    
    print("\n무작위 샘플 레코드:")
    for record in sample_records:
        print(record)

    # 각 컬럼의 기본 통계 계산 (수치형 컬럼에 대해)
    numeric_columns = ['price', 'regularPrice', 'discountRate', 'studentCount', 'reviewCount', 'star']
    # print("\n수치형 컬럼의 기본 통계:")
    # for column in numeric_columns:
    #     cursor.execute(f"SELECT MIN({column}), MAX({column}), AVG({column}) FROM courses")
    #     min_val, max_val, avg_val = cursor.fetchone()
    #     print(f"{column}: Min = {min_val}, Max = {max_val}, Avg = {avg_val:.2f}")

    # 각 컬럼의 null 값 개수 확인
    cursor.execute("PRAGMA table_info(courses)")
    columns = [column[1] for column in cursor.fetchall()]
    
    print("\n각 컬럼의 null 값 개수:")
    for column in columns:
        cursor.execute(f"SELECT COUNT(*) FROM courses WHERE {column} IS NULL")
        null_count = cursor.fetchone()[0]
        print(f"{column}: {null_count}")

    # 가장 최근에 업데이트된 레코드와 가장 오래된 레코드 확인
    cursor.execute("SELECT * FROM courses ORDER BY last_updated DESC LIMIT 1")
    print("\n가장 최근에 업데이트된 레코드:")
    print(cursor.fetchone())
    
    cursor.execute("SELECT * FROM courses ORDER BY last_updated ASC LIMIT 1")
    print("\n가장 오래된 레코드:")
    print(cursor.fetchone())

    # 연결 종료
    conn.close()

if __name__ == '__main__':
    test_database()
# Out:
# 총 레코드 수: 3457
#
# 무작위 샘플 레코드:
# (331619, '퇴근은 빠르게, 코드는 클린하게, 인텔리J를 활용한 리팩토링 시작하기(with 단축키) - 기초편', '겸손하게 익은 벼', None, None, None, 62, 3, 5.0, '2024-07-01 09:53:38')
# (329541, '외워서 끝내는 네트워크 핵심이론 - 응용', '널널한 개발자', None, None, None, 3071, 84, 4.9, '2024-07-01 09:52:53')
# (332258, 'Verilog FPGA Program 4 (MCU Porting, HIL-A35T)', 'alex', None, None, None, 17, 0, 0.0, '2024-07-01 09:53:31')
# (334104, 'Amazing JavaScript - 입문', '장기효(캡틴판교)', None, None, None, 588, 7, 5.0, '2024-07-01 09:52:54')
# (324841, '[애플 공식 교재] iOS 앱 만들기 Part1', '코더스하이', None, None, None, 273, 6, 5.0, '2024-07-01 09:53:52')
#
# 각 컬럼의 null 값 개수:
# id: 0
# title: 0
# instructor: 0
# price: 3457
# regular_price: 3457
# discount_rate: 3457
# student_count: 0
# review_count: 0
# rating: 0
# last_updated: 0
#
# 가장 최근에 업데이트된 레코드:
# (23026, '테레비보다 재미있는 제이쿼리(jQuery) 강좌', '샵투월드', None, None, None, 4973, 84, 4.3, '2024-07-01 09:54:06')
#
# 가장 오래된 레코드:
# (172458, 'IntelliJ를 시작하시는 분들을 위한 IntelliJ 가이드', '향로', None, None, None, 2291, 165, 4.7, '2024-07-01 09:52:53')

# %%
# 데이터베이스 연결
conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# 테이블의 모든 데이터 조회
cursor.execute("SELECT * FROM courses")
rows = cursor.fetchall()

# 결과 출력
for row in rows:
    print(row)

# 데이터 개수 확인
cursor.execute("SELECT COUNT(*) FROM courses")
count = cursor.fetchone()[0]
print(f"총 {count}개의 강의가 저장되어 있습니다.")

# 연결 종료
conn.close()
# Out:
# (18968, '따라하면서 배우는 웹애플리케이션 만들기', 'Egoing Lee', None, None, None, 6385, 82, 5.0, '2024-07-01 09:53:47')
# (19174, '생활코딩 - HTML 기초', 'Egoing Lee', None, None, None, 9217, 165, 4.9, '2024-07-01 09:53:53')
# (19271, '생활코딩 - jQuery', 'Egoing Lee', None, None, None, 6227, 155, 4.9, '2024-07-01 09:53:47')
# (19671, 'TED – 자기계발', '유용한IT학습', None, None, None, 1627, 44, 4.5, '2024-07-01 09:54:02')
# (19687, '안드로이드 기초부터 창업까지 - 실무 강좌', 'Seoul Wiz', None, None, None, 4986, 25, 4.8, '2024-07-01 09:54:05')
# (19812, '생활코딩 - MySQL', 'Egoing Lee', None, None, None, 8834, 101, 4.9, '2024-07-01 09:53:53')
# (19885, '생활코딩 - PHP 기본 A 부터 Z 까지', 'Egoing Lee', None, None, None, 6114, 63, 4.8, '2024-07-01 09:53:34')
# (19889, '아이폰 앱 제작기 – 원트소프트 꼬마마녀 샐리', 'Choong Ji Kim', None, None, None, 778, 10, 4.6, '2024-07-01 09:54:05')
# (20117, '웹브라우저 Javascript (자바스크립트)', 'Egoing Lee', None, None, None, 9412, 170, 4.9, '2024-07-01 09:53:42')
# (20275, '생활코딩 - 정규표현식', 'Egoing Lee', None, None, None, 3481, 132, 4.9, '2024-07-01 09:53:53')
# (20303, '타이젠 강좌', 'Seoul Wiz', None, None, None, 606, 8, 5.0, '2024-07-01 09:54:05')
# (20319, '빠르게 활용 가능한 파이썬 3.2 프로그래밍', '유용한IT학습', None, None, None, 2047, 22, 3.9, '2024-07-01 09:54:05')
# (20607, '실전 HTML & CSS 강좌', 'Seoul Wiz', None, None, None, 10955, 113, 4.8, '2024-07-01 09:54:02')
# (20701, '노리섬의 프리미어 강좌\xa0(Adobe Premiere)', '유용한IT학습', None, None, None, 3869, 24, 4.2, '2024-07-01 09:53:49')
# (21831, '섹쉬 PHP 강좌 - PHP 기본부터 MYSQL, XML, 네이버쇼핑검색 을 이용한 활용까지', '샵투월드', None, None, None, 2579, 6, 5.0, '2024-07-01 09:54:05')
# (21946, "'이것이 리눅스다' 저자의 Red Hat CentOS7 리눅스 서버&네트워크 강좌", '한빛미디어', None, None, None, 12287, 128, 4.8, '2024-07-01 09:54:02')
# (22152, '뇌를 자극하는 윈도우즈 시스템 프로그래밍', '한빛미디어', None, None, None, 4605, 42, 4.9, '2024-07-01 09:54:05')
# (22421, '스타트업, 초기 기업을 위한 실용적 세무 이야기', 'Meet Advisor', None, None, None, 1669, 33, 4.6, '2024-07-01 09:54:05')
# (22461, '아두이노 강좌', '유용한IT학습', None, None, None, 3739, 32, 4.9, '2024-07-01 09:53:43')
# (22513, '혼자 공부하는 C 언어 저자에게 배우는 C 언어의 모든 것', '한빛미디어', None, None, None, 10504, 56, 4.9, '2024-07-01 09:54:05')
# (22635, '기본을 확실히!! HTML의 모든 것', 'Egoing Lee', None, None, None, 14966, 418, 5.0, '2024-07-01 09:53:34')
# (22750, 'Zbrush 이용한 공룡, 공룡책 제작과정 으로 배우는 3D 모델링 배우기', '비타민상상력', None, None, None, 55, 2, 4.5, '2024-07-01 09:54:03')
# (22811, '소스트리(source tree) 를 사용하여 Git 사용하기', 'Egoing Lee', None, None, None, 5998, 160, 4.9, '2024-07-01 09:53:53')
# (22902, '인터넷 기본 도메인 , 호스트, 포워딩 알아보기', 'Egoing Lee', None, None, None, 3088, 66, 4.9, '2024-07-01 09:53:47')
# (22933, '유니티 2D 로그라이크 게임 만들기 [한글자막]', '유용한IT학습', None, None, None, 6913, 43, 4.7, '2024-07-01 09:53:43')
# (22995, 'ATOM Editor 소개 및 사용법', 'Egoing Lee', None, None, None, 4388, 214, 4.9, '2024-07-01 09:53:34')
# (23026, '테레비보다 재미있는 제이쿼리(jQuery) 강좌', '샵투월드', None, None, None, 4973, 84, 4.3, '2024-07-01 09:54:06')
# (23133, '여러가지 개발자 도구 사용법', 'Egoing Lee', None, None, None, 1534, 25, 4.8, '2024-07-01 09:53:47')
# (23396, '유니티 기초 강좌 - 기획부터 사용까지', '유용한IT학습', None, None, None, 12818, 152, 4.6, '2024-07-01 09:53:49')
# (23573, '[포토샵 혁명 방송] 포토샵 고급 완성 - 펜툴 마스터 하기', '유용한IT학습', None, None, None, 4106, 15, 4.9, '2024-07-01 09:53:54')
# (24147, '워드프레스 쇼핑몰(우커머스) 제작 따라하기', '유용한IT학습', None, None, None, 1641, 16, 4.3, '2024-07-01 09:53:54')
# (24208, '게임 만들면서 배우는 재미있는 스크래치 프로그래밍', 'Egoing Lee', None, None, None, 2269, 32, 4.9, '2024-07-01 09:53:34')
# (24360, '초절정 파이썬 강좌 (python)', '샵투월드', None, None, None, 5396, 81, 4.1, '2024-07-01 09:54:05')
# (24401, '실전 파이썬 게임 만들기 (Pygame)', '샵투월드', None, None, None, 5122, 29, 4.9, '2024-07-01 09:54:03')
# (24836, '[포토샵 혁명 방송] 포토샵 기초 완성', '유용한IT학습', None, None, None, 11119, 31, 4.8, '2024-07-01 09:53:30')
# (25141, '어셈블리어 배우기', '유용한IT학습', None, None, None, 3928, 27, 4.6, '2024-07-01 09:53:49')
# (25295, '디즈니 애니메이션 스튜디오 look dev artist 에게 배우는 Mari 2.0 사용법', 'Berdandyss', None, None, None, 162, 5, 3.6, '2024-07-01 09:53:58')
# (25380, '토튜의 따라하면서 게임을 만드는 유니티 NGUI 강좌', 'totuworld', None, None, None, 1663, 9, 5.0, '2024-07-01 09:54:05')
# (25676, '왕초보를 위한 스위프트 프로그래밍 강좌 (iOS app with xcode&swift)', '유용한IT학습', None, None, None, 6737, 50, 4.7, '2024-07-01 09:53:58')
# (25719, '창원대학교 박동규 교수의 Swift 언어 기초 강좌', 'Donggyu Park', None, None, None, 2015, 21, 5.0, '2024-07-01 09:54:06')
# (25750, 'id software 3D 아티스트에게 배우는 Maya 3D 모델링 입문', 'Sup Choi', None, None, None, 244, 5, 5.0, '2024-07-01 09:54:03')
# (25942, 'C++ 로 배우는 자료구조와 알고리즘', '유용한IT학습', None, None, None, 8151, 21, 4.3, '2024-07-01 09:53:54')
# (26452, '[C# 중급 강좌] 라이브러리 만들기', 'alongside74', None, None, None, 3451, 76, 4.9, '2024-07-01 09:53:58')
# (26468, '[C# 초보 강좌] 예제로 배우는 C#', 'alongside74', None, None, None, 9352, 156, 4.9, '2024-07-01 09:54:03')
# (26505, '마모셋 툴백 (marmoset toolbag) 렌더 무료강좌', 'Sup Choi', None, None, None, 1211, 13, 5.0, '2024-07-01 09:54:06')
# (26549, 'Zbrush 4R6 입문에서 마스터 까지 Zbrush 4R6 의 모든것', 'Sup Choi', None, None, None, 241, 5, 4.0, '2024-07-01 09:54:03')
# (26980, '파이썬을 이용한 웹 크롤링(Web Crawling) 어플리케이션 만들기', 'onecue', None, None, None, 8861, 64, 4.6, '2024-07-01 09:54:05')
# (27071, '생활코딩 - 자바스크립트(JavaScript) 기본', 'Egoing Lee', None, None, None, 25270, 437, 4.9, '2024-07-01 09:53:42')
# (27195, '누구나 쉽게 따라하며 배우는 - 애프터이펙트 입문 강좌', '송승빈', None, None, None, 192, 7, 4.1, '2024-07-01 09:54:02')
# (27256, 'Django 초보 가이드 - 실습을 통해 알아보는 장고 입문', 'onecue', None, None, None, 11074, 306, 4.7, '2024-07-01 09:54:02')
# (27267, 'iOS9 & Swift2 12개 앱을 만들면서 배우는 아이폰 앱 개발', '뭐하는거니?', None, None, None, 375, 17, 4.9, '2024-07-01 09:53:58')
# (27277, 'iOS10 아이폰 웹브라우저 Swift3 로 만들기 실습', '뭐하는거니?', None, None, None, 1427, 35, 4.7, '2024-07-01 09:53:58')
# (27796, 'C 와 C++ 을 동시에 배워보자 - 두들낙서의 C/C++', '두들낙서', None, None, None, 16622, 132, 4.9, '2024-07-01 09:54:05')
# (28083, 'AWS (아마존 웹서비스) 가입부터 활용까지', 'Egoing Lee', None, None, None, 7901, 169, 4.9, '2024-07-01 09:53:42')
# (28192, 'MIT 공개강좌 - 컴퓨터 과학 & 프로그래밍 입문 (python)', '유용한IT학습', None, None, None, 3745, 13, 4.7, '2024-07-01 09:54:02')
# (28280, 'Objective-C 강좌 - 12개 앱 만들면서 배우는 iOS 아이폰 앱 개발', '뭐하는거니?', None, None, None, 811, 39, 4.7, '2024-07-01 09:53:58')
# (28516, 'Maya 하드서페이스 모델링 강좌', 'wtemodeler', None, None, None, 42, 0, 0.0, '2024-07-01 09:54:03')
# (28579, '3DS MAX 입문강좌 (입문부터 자동차 예제까지)', '목마하임(MokmaHeim)', None, None, None, 2171, 42, 4.7, '2024-07-01 09:53:34')
# (29020, 'Objective-C 를 이용해 iOS9 아이폰 웹브라우저 만들기', '뭐하는거니?', None, None, None, 1019, 26, 4.8, '2024-07-01 09:54:05')
# (29181, '라이노 3D 모델링 실전 예제 - 향수병, Zero three 스피커 모델링', '권경범', None, None, None, 1080, 4, 4.5, '2024-07-01 09:54:06')
# (29421, '자바 디자인 패턴의 이해 - Gof Design Pattern', 'garam park', None, None, None, 8795, 79, 4.6, '2024-07-01 09:54:05')
# (29707, '모두를 위한 딥러닝 - 기본적인 머신러닝과 딥러닝 강좌', 'Sung Kim', None, None, None, 25831, 249, 4.9, '2024-07-01 09:53:53')
# (29978, 'Git 과 Redmine 으로 하는 프로젝트 관리', 'garam park', None, None, None, 2984, 29, 4.4, '2024-07-01 09:54:06')
# (30105, '스크래치로 배우는 알고리즘', '유용한IT학습', None, None, None, 1731, 16, 4.6, '2024-07-01 09:53:43')
# (30240, 'Node.js를 이용해 웹 애플리케이션 만들기', 'Egoing Lee', None, None, None, 13164, 426, 4.9, '2024-07-01 09:53:53')
# (30495, 'Node.js로 데이터베이스 다루고 웹 애플리케이션 만들기', 'Egoing Lee', None, None, None, 5999, 68, 4.9, '2024-07-01 09:53:42')
# (30881, 'Node.Js 활용하기', 'Egoing Lee', None, None, None, 5976, 39, 4.9, '2024-07-01 09:53:53')
# (31044, '널널한 박교수의 C 강좌 고급편', 'Donggyu Park', None, None, None, 2328, 16, 4.7, '2024-07-01 09:53:53')
# (31275, '쉽게 배우는 ZBrush 입문 강좌', '목마하임(MokmaHeim)', None, None, None, 4664, 35, 4.8, '2024-07-01 09:53:42')
# (31323, '아이폰 ios 개발 강좌 - 앱 12개를 만들며 배우는 Swift3 & iOS10', '뭐하는거니?', None, None, None, 694, 25, 4.7, '2024-07-01 09:53:47')
# (31327, '3dsmax 초급부터 전문가까지 - 한방에 끝내는 3dsmax 강좌', '목마하임(MokmaHeim)', None, None, None, 1378, 38, 5.0, '2024-07-01 09:53:14')
# (32184, '잘쓰는 기능만 쏙 뽑아 배우는 파워포인트 Quick Start', 'topmentor', None, None, None, 5721, 137, 4.8, '2024-07-01 09:54:03')
# (32235, 'PHP 기초강좌 - 쩡원의 게시판 홈페이지 제작 무작정 따라하기', '유용한IT학습', None, None, None, 2764, 19, 4.6, '2024-07-01 09:53:43')
# (32320, '빅데이터의 통찰력을 키워주는 엑셀 Quick Start', 'topmentor', None, None, None, 16452, 326, 4.9, '2024-07-01 09:54:02')
# (32377, '쉽게 만드는 웹페이지 - IUEditor 사용법', '아이유에디터', None, None, None, 1158, 15, 4.2, '2024-07-01 09:54:03')
# (32456, '영리한 프로그래밍을 위한 알고리즘 강좌', '권오흠', None, None, None, 31461, 134, 4.7, '2024-07-01 09:53:58')
# (32621, 'React & Express 를 이용한 웹 어플리케이션 개발하기', 'velopert(김 민준)', None, None, None, 17884, 135, 4.8, '2024-07-01 09:53:58')
# (33167, 'AngularJS 기본 개념과 To-Do 앱 만들기 실습 - 앵귤러 강좌', 'WePlanet Official ', None, None, None, 6310, 141, 4.7, '2024-07-01 09:53:27')
# (33309, 'Stanford iOS 한글자막 강의', '한글링', None, None, None, 6174, 46, 4.8, '2024-07-01 09:54:05')
# (33440, 'C로 배우는 자료구조 및 여러가지 예제 실습', '권오흠', None, None, None, 10602, 65, 4.8, '2024-07-01 09:53:47')
# (34221, 'CSS 기본부터 활용까지', 'Egoing Lee', None, None, None, 9474, 227, 5.0, '2024-07-01 09:53:34')
# (34507, '초보자를 위한 AWS 클라우드 시작하기', '유용한IT학습', None, None, None, 6017, 130, 4.6, '2024-07-01 09:53:49')
# (34545, '나의 첫 Django 앱 만들기', 'schoolofweb.net', None, None, None, 6667, 63, 4.3, '2024-07-01 09:54:06')
# (34835, '성공적인 코딩 인터뷰를 위한 코딩 인터뷰 정복하기 - 코딩 테스트', 'Minsuk Heo', None, None, None, 7915, 73, 4.8, '2024-07-01 09:53:53')
# (35317, '게임학개론', '나우IT', None, None, None, 2489, 42, 4.8, '2024-07-01 09:54:03')
# (35834, '모의해킹이란 무엇인가 - 진로편', '보안프로젝트', None, None, None, 141, 9, 4.8, '2024-07-01 09:53:16')
# (35862, 'IT 직장인들을 위한 책쓰기 강의', '보안프로젝트', None, None, None, 105, 8, 4.0, '2024-07-01 09:53:36')
# (36361, '메타스플로잇(Metasploit) 활용한 취약점 분석(초중급과정)', '보안프로젝트', None, None, None, 537, 56, 4.7, '2024-07-01 09:53:30')
# (36577, '윈도우즈 애플리케이션 취약점 분석 입문부터 활용까지', '보안프로젝트', None, None, None, 442, 31, 4.3, '2024-07-01 09:53:43')
# (36848, '악성코드 분석을 위한 메모리 포렌식 (memory forensic)', '보안프로젝트', None, None, None, 385, 29, 4.5, '2024-07-01 09:53:09')
# (36950, '생활코딩 - Linux', 'Egoing Lee', None, None, None, 14656, 266, 4.9, '2024-07-01 09:53:34')
# (37004, '메타스플로잇(Metasploit) 활용한 취약점 분석(중고급과정)', '보안프로젝트', None, None, None, 229, 20, 4.5, '2024-07-01 09:53:30')
# (37069, 'ELK 스택 (ElasticSearch, Logstash, Kibana) 으로 데이터 분석', 'Minsuk Heo', None, None, None, 13177, 292, 4.8, '2024-07-01 09:54:02')
# (37468, '아이오닉(ionic2) 개발을 위한 타입스크립트 기본', '차정민', None, None, None, 1872, 29, 4.4, '2024-07-01 09:53:58')
# (37760, '보안 전문가를 위한 파워쉘', '보안프로젝트', None, None, None, 397, 44, 4.7, '2024-07-01 09:53:16')
# (38060, 'Sencha ExtJS 6 로 화면개발 더이상 고민하지 말자 - 기초편', '개발로짜', None, None, None, 1623, 27, 4.9, '2024-07-01 09:53:58')
# (38171, '파이어베이스(Firebase)를 이용한 웹+안드로이드 메모 어플리케이션 만들기', '신휴창', None, None, None, 8008, 63, 4.6, '2024-07-01 09:54:05')
# (38195, '안드로이드 스튜디오로 안드로이드 앱 만들기', '안경잡이개발자', None, None, None, 14585, 66, 4.3, '2024-07-01 09:53:58')
# (38407, '모두를 위한 딥러닝 - Deep Reinforcement Learning', 'Sung Kim', None, None, None, 9936, 89, 5.0, '2024-07-01 09:53:47')
# (38528, '안드로이드 모바일 앱 모의해킹과 시큐어코딩', '보안프로젝트', None, None, None, 602, 53, 4.7, '2024-07-01 09:53:30')
# (38647, '비박스를 활용한 웹 모의해킹 완벽 실습', '보안프로젝트', None, None, None, 454, 46, 4.7, '2024-07-01 09:53:22')
# (38769, '오픈 소스 도구를 활용한 웹 해킹 및 스노트 분석(침해대응)', '보안프로젝트', None, None, None, 495, 42, 4.6, '2024-07-01 09:53:16')
# (39185, 'OpenCV 를 활용한 명함인식 기능 구현 강좌', '마이캠퍼스', None, None, None, 647, 41, 4.5, '2024-07-01 09:53:58')
# (40067, '부트스트랩으로 개인 홈페이지 만들기', '안경잡이개발자', None, None, None, 6986, 152, 4.5, '2024-07-01 09:54:05')
# (40164, '테스트주도개발(TDD)로 만드는 NodeJS API 서버', '김정환', None, None, None, 2168, 176, 4.7, '2024-07-01 09:53:18')
# (40565, '애자일 개발 방법론 개념과 실제 적용하기', '이재왕', None, None, None, 384, 62, 4.7, '2024-07-01 09:53:43')
# (40619, '이것이 우분투 리눅스다', '한빛미디어', None, None, None, 6802, 60, 4.8, '2024-07-01 09:53:58')
# (41183, '정보보안 전문가란? 무엇을 하고 어떻게 준비해야 할까.', '보안프로젝트', None, None, None, 7404, 276, 4.8, '2024-07-01 09:53:30')
# (41871, 'Sencha ExtJS 6 로 웹 어플리케이션 만들기- 실전/응용편', '개발로짜', None, None, None, 681, 10, 5.0, '2024-07-01 09:54:05')
# (44857, '누구나 따라하면서 배우는 JSP 커뮤니티 게시판 만들기', '안경잡이개발자', None, None, None, 7591, 172, 4.4, '2024-07-01 09:54:05')
# (44932, '모의해킹 업무의 이해', '보안프로젝트', None, None, None, 3775, 88, 4.7, '2024-07-01 09:53:48')
# (45075, '야곰의 스위프트 기본 문법 강좌', 'yagom', None, None, None, 5671, 133, 4.8, '2024-07-01 09:54:02')
# (46335, '유니티 게임 개발 (Unity 2D) - 시작부터 배포까지', '스터디 인코딩', None, None, None, 1769, 72, 4.6, '2024-07-01 09:53:42')
# (47007, 'OpenCV 강좌 - 컴퓨터 비전', 'Jeonghyun Kim', None, None, None, 7751, 40, 4.8, '2024-07-01 09:53:39')
# (47893, '자바스크립트로 알아보는 함수형 프로그래밍 (ES5)', '유인동', None, None, None, 12740, 303, 4.9, '2024-07-01 09:53:21')
# (50398, '타입스크립트 코리아 : 기초 세미나', '이웅재', None, None, None, 5103, 60, 4.6, '2024-07-01 09:54:05')
# (51560, 'R 프로그램 - 시즌 1', 'seounglim45', None, None, None, 5762, 119, 4.7, '2024-07-01 09:54:05')
# (52774, '그로스해킹 핵심 강좌 - Growth Hacking Fundamentals', 'Steve Seo', None, None, None, 132, 6, 3.7, '2024-07-01 09:54:02')
# (53156, 'Angular 기본과 간단한 To-Do 어플리케이션 만들기', 'Jeado Ko', None, None, None, 3950, 124, 4.8, '2024-07-01 09:54:03')
# (53186, '마인크래프트 게임을 활용한 파이썬 프로그래밍 완벽 이해', '보안프로젝트', None, None, None, 351, 21, 4.7, '2024-07-01 09:53:22')
# (57135, 'XE3 사이트제작 튜토리얼', '유용한IT학습', None, None, None, 430, 12, 4.7, '2024-07-01 09:53:48')
# (57761, '파이어베이스를 활용한 메신져 만들기 - Android', '신휴창', None, None, None, 313, 18, 4.2, '2024-07-01 09:53:47')
# (58058, '자바(JAVA) 언어 기본 강좌', '나우IT', None, None, None, 6652, 70, 4.5, '2024-07-01 09:54:03')
# (59014, '만들어 가면서 배우는 JAVA 플레이그라운드', '호눅스', None, None, None, 7921, 94, 4.6, '2024-07-01 09:54:02')
# (59172, '새차원의 코틀린(Kotlin) 강좌', '새차원', None, None, None, 8329, 75, 4.5, '2024-07-01 09:54:05')
# (59977, '타입스크립트 코리아 : React with TypeScript 세미나', '이웅재', None, None, None, 5573, 30, 4.8, '2024-07-01 09:54:06')
# (62635, 'Illustrator CC - 일러스트레이터 입문부터 실전까지 한번에 마스터하기', '클로이', None, None, None, 541, 29, 4.9, '2024-07-01 09:53:58')
# (62954, 'iOS AutoLayout을 활용한 실전 UI구성 전략 - 카카오톡 같은 고급 UI 만들기', 'iOS Developer - 이정', None, None, None, 499, 41, 4.8, '2024-07-01 09:53:51')
# (63179, '초보도 쉽게 할 수 있는 아이폰 어플(iOS App) 만들기', 'OnArcher', None, None, None, 90, 1, 5.0, '2024-07-01 09:53:42')
# (64058, 'Java로 배우는 자료구조', '권오흠', None, None, None, 13701, 145, 4.8, '2024-07-01 09:53:47')
# (65096, '퓨즈 스터디를 원하다 [Wonhada]', '원강민', None, None, None, 497, 10, 4.5, '2024-07-01 09:54:03')
# (66242, '네트워크 패킷 분석 입문 및 악성코드 샘플 분석', '보안프로젝트', None, None, None, 946, 101, 4.8, '2024-07-01 09:53:16')
# (66307, "'해킹대회 문제'로 배우는 파일시스템 이해/실습", '보안프로젝트', None, None, None, 79, 6, 3.3, '2024-07-01 09:53:43')
# (66940, '인슈의 게임 캐릭터 포토샵 디자인&원화 입문자편', '박인수', None, None, None, 107, 6, 3.5, '2024-07-01 09:54:05')
# (66962, '인슈의 캐주얼 게임 캐릭터 원화', '박인수', None, None, None, 102, 1, 5.0, '2024-07-01 09:53:58')
# (68285, '타입스크립트 코리아 : Electron with TypeScript Hands-On Labs 세미나', '이웅재', None, None, None, 141, 2, 5.0, '2024-07-01 09:53:54')
# (70212, "C++ Let's Make Games", '노근석', None, None, None, 6741, 32, 4.8, '2024-07-01 09:54:03')
# (70475, 'Rails로 쉽고 빠른 웹사이트 만들기(Ruby Coin)', 'Karoid', None, None, None, 2419, 56, 4.8, '2024-07-01 09:54:06')
# (71741, '80여개 예제로 알아보는 쉽고 재미있는 [데이터 시각화]', '김지형', None, None, None, 150, 16, 4.5, '2024-07-01 09:53:49')
# (71918, '파이썬을 이용한 IT 해킹과 보안', '보안프로젝트', None, None, None, 731, 60, 4.7, '2024-07-01 09:53:22')
# (77623, '[김왼손의 왼손코딩] 미운코딩새끼: 4시간 만에 끝내는 파이썬 기초 (전자책 포함)', '김왼손의 왼손코딩', None, None, None, 18083, 525, 4.9, '2024-07-01 09:53:38')
# (86219, '아빠가 들려주는 [R shiny app] 만들기', '김지형', None, None, None, 1245, 30, 4.9, '2024-07-01 09:54:02')
# (87739, '파이썬스쿨 - 파이썬 프로그래밍을 이용한 업무 자동화', '보안프로젝트', None, None, None, 387, 43, 4.7, '2024-07-01 09:53:22')
# (88587, '컴퓨터, 웹, 코딩, 프로그래밍의 시작 - Web1', 'Egoing Lee', None, None, None, 16122, 635, 4.9, '2024-07-01 09:53:42')
# (89565, 'MongoDB - Javascript로 배우는 NoSQL DB', 'Karoid', None, None, None, 380, 24, 3.8, '2024-07-01 09:54:05')
# (90196, '앱 12개를 만들며 배우는 Swift4 & iOS11 아이폰 iOS 개발 강좌', '뭐하는거니?', None, None, None, 885, 48, 4.5, '2024-07-01 09:53:53')
# (92325, '앵귤러 기초 세미나', '이웅재', None, None, None, 220, 11, 4.8, '2024-07-01 09:53:48')
# (94779, '언리얼 엔진 4 : Intro to Blueprints', '유용한IT학습', None, None, None, 3661, 85, 4.9, '2024-07-01 09:53:43')
# (97864, 'My Location - ionic3 와 Google Map Api 를 활용한 내 위치 정보 찾기', '김철현', None, None, None, 839, 17, 5.0, '2024-07-01 09:54:03')
# (101037, '코어 자바스크립트', '정재남', None, None, None, 3845, 273, 4.8, '2024-07-01 09:53:09')
# (101297, 'Ionic3+Firebase를 이용한 Email/Password 사용자 인증', '김철현', None, None, None, 1140, 24, 4.9, '2024-07-01 09:54:03')
# (101573, '머신러닝 이론 및 파이썬 실습', 'Minsuk Heo', None, None, None, 10088, 142, 4.8, '2024-07-01 09:54:02')
# (105899, '윈도우 악성코드(malware) 분석 입문 과정', '보안프로젝트', None, None, None, 900, 90, 4.7, '2024-07-01 09:53:09')
# (107793, '실습 UI 개발로 배워보는 순수 javascript 와 VueJS 개발', '김정환', None, None, None, 2169, 121, 4.7, '2024-07-01 09:53:32')
# (109337, 'WEB2 - CSS', 'Egoing Lee', None, None, None, 4524, 354, 5.0, '2024-07-01 09:53:53')
# (109710, 'WEB2 - JavaScript', 'Egoing Lee', None, None, None, 8487, 328, 4.9, '2024-07-01 09:53:47')
# (111762, 'C 프로그래밍 - 입문부터 게임 개발까지', '나도코딩', None, None, None, 23286, 264, 4.8, '2024-07-01 09:54:02')
# (113593, '유니티 게임 개발 (2D) 실전편 - 스크립트는 물론, 디자인 패턴과 알고리즘까지', '스터디 인코딩', None, None, None, 542, 22, 4.4, '2024-07-01 09:53:47')
# (116298, '아이폰 앱 개발 입문 1편', '최완택', None, None, None, 5584, 200, 4.9, '2024-07-01 09:53:47')
# (119035, '엔트리 기초부터 활용까지 정글코딩!', '정글코딩(JungleCoding)', None, None, None, 519, 14, 5.0, '2024-07-01 09:54:02')
# (119133, '만들면서 배우는 인공지능(강화학습 편)', '최광성', None, None, None, 92, 8, 3.9, '2024-07-01 09:54:06')
# (119166, 'GPU 프로그래밍 언어 CUDA(쿠다) 기초', '최광성', None, None, None, 167, 17, 4.2, '2024-07-01 09:54:06')
# (119293, 'DATABASE 1&2 - MySQL', 'Egoing Lee', None, None, None, 8492, 323, 4.9, '2024-07-01 09:53:34')
# (119505, '직접 등록하는 iMessage Sticker', 'eungen joo', None, None, None, 14, 1, 5.0, '2024-07-01 09:54:03')
# (120858, '아이오닉으로 오프라인 퍼스트 웹 (offline first web) 만들기', '김철현', None, None, None, 17, 1, 5.0, '2024-07-01 09:53:57')
# (120905, '겜팔이의 안드로이드 세뇌교실 - 인★그램 개발부터 배포까지', '겜팔이', None, None, None, 4101, 20, 4.4, '2024-07-01 09:53:57')
# (121163, 'Spring framework 개발 환경 구축하기와 Dao 리팩토링하기', 'Kyeongrok Kim', None, None, None, 186, 12, 4.6, '2024-07-01 09:54:01')
# (121703, '파이썬 입문 및 웹 크롤링을 활용한 다양한 자동화 어플리케이션 제작하기', '좋은사람', None, None, None, 2199, 105, 4.7, '2024-07-01 09:53:25')
# (121889, '1인 스타트업 CEO를 위한 IT 서비스 활용 노하우', '박윤종', None, None, None, 15, 2, 4.5, '2024-07-01 09:54:03')
# (122560, '직장인을 위한 프로그래밍 입문과 업무자동화 활용', 'SungYong Lee', None, None, None, 524, 64, 4.5, '2024-07-01 09:53:31')
# (123867, 'WEB2 - PHP', 'Egoing Lee', None, None, None, 2380, 82, 4.9, '2024-07-01 09:53:47')
# (124517, '[디퍼런테이션] PPT 제작의 필수 강의', 'WonYoung Choi', None, None, None, 270, 20, 4.8, '2024-07-01 09:53:21')
# (124631, '배웠는데 못 쓰겠는 CSS 구출기', 'sonack', None, None, None, 40, 1, 5.0, '2024-07-01 09:53:53')
# (124917, '쉽고 자연스럽게 배워보는 Javascript 입문 - 코드스쿼드 마스터즈 코스 레벨1', '호눅스', None, None, None, 1199, 50, 4.6, '2024-07-01 09:53:47')
# (125228, '구글 애드워즈 - 캠페인 유형별로 모아서보기', '유용한IT학습', None, None, None, 1664, 11, 4.4, '2024-07-01 09:53:22')
# (125821, '구성 관리 자동화 도구 - 앤서블(Ansible)', '조훈(Hoon Jo)', None, None, None, 554, 31, 4.8, '2024-07-01 09:53:12')
# (126956, '야곰의 iOS 프로그래밍', 'yagom', None, None, None, 521, 33, 4.3, '2024-07-01 09:53:57')
# (129277, 'WEB3 - PHP & MySQL', 'Egoing Lee', None, None, None, 2661, 50, 5.0, '2024-07-01 09:53:34')
# (129563, 'R 프로그램 - 시즌2', 'seounglim45', None, None, None, 1657, 27, 5.0, '2024-07-01 09:54:01')
# (129621, 'C# 네트워크 프로그래밍', '나우IT', None, None, None, 3257, 59, 4.8, '2024-07-01 09:54:01')
# (129782, 'WEB2 - Python 기초', 'Egoing Lee', None, None, None, 3426, 48, 5.0, '2024-07-01 09:53:47')
# (130286, 'CSS에 날개를 달아주는 Sass (SCSS)', 'DEvSIGNER', None, None, None, 604, 55, 4.5, '2024-07-01 09:54:01')
# (131555, '코코아코딩, 스크래치 게임만들기!', '정글코딩(JungleCoding)', None, None, None, 557, 11, 4.8, '2024-07-01 09:54:03')
# (132388, '회사에서 바로 통하는 엑셀 2016', '한빛미디어', None, None, None, 3319, 85, 4.7, '2024-07-01 09:54:01')
# (133534, 'Pandas 팬더스 데이터분석 기초 실습', 'Minsuk Heo', None, None, None, 6888, 292, 4.8, '2024-07-01 09:53:57')
# (133903, '엑셀을 활용한 VBA 업무 자동화', 'Kyeongrok Kim', None, None, None, 119, 15, 3.9, '2024-07-01 09:53:57')
# (133944, '어도비 XD로 프로토타입 제작하기', 'sim', None, None, None, 54, 7, 3.4, '2024-07-01 09:53:47')
# (134573, '화이트해커가 되기 위한 8가지 웹 해킹 기술', '시큐아카데미', None, None, None, 6359, 154, 4.9, '2024-07-01 09:54:03')
# (135947, '캐글 실습으로 배우는 데이터 사이언스', '박조은', None, None, None, 4264, 58, 4.8, '2024-07-01 09:53:31')
# (135995, '프로들만의 차별화된 엑셀 데이터 분석과 차트 시각화', '엑셀여신', None, None, None, 562, 85, 5.0, '2024-07-01 09:53:44')
# (136498, 'Vue.js 중급 강좌 - 웹앱 제작으로 배워보는 Vue.js, ES6, Vuex', '장기효(캡틴판교)', None, None, None, 6116, 589, 4.9, '2024-07-01 09:52:59')
# (138829, '지옥에서 온 Git', 'Egoing Lee', None, None, None, 9369, 186, 5.0, '2024-07-01 09:53:42')
# (139621, '14일만에 배우는 ASP.NET CORE', '김정수', None, None, None, 538, 19, 4.4, '2024-07-01 09:53:34')
# (139755, '게임 보안 입문을 위한 치트엔진 튜토리얼', '보안프로젝트', None, None, None, 1928, 21, 5.0, '2024-07-01 09:53:43')
# (140728, '레트로의 유니티 C# 게임 프로그래밍 에센스', '이제민', None, None, None, 1711, 85, 4.8, '2024-07-01 09:53:34')
# (140911, 'Firebase 서버를 통한 Android앱 HowlTalk 만들기', '하울', None, None, None, 1960, 11, 4.4, '2024-07-01 09:54:03')
# (141297, '모의해킹 업무 이해, 두번째 이야기', '보안프로젝트', None, None, None, 1802, 33, 4.8, '2024-07-01 09:53:36')
# (141810, 'Firebase 서버를 통한 IOS앱 HowlTalk 만들기', '하울', None, None, None, 1701, 14, 4.9, '2024-07-01 09:54:01')
# (141971, 'Firebase 서버를 통한 IOS앱 개발 지침서', '하울', None, None, None, 1392, 10, 4.8, '2024-07-01 09:54:01')
# (142047, 'Firebase 서버를 통한 Android앱 개발 지침서', '하울', None, None, None, 2535, 14, 4.6, '2024-07-01 09:54:03')
# (143320, 'WEB2 - Home server', 'Egoing Lee', None, None, None, 1692, 96, 4.9, '2024-07-01 09:53:42')
# (143476, 'WEB2 - Domain Name System', 'Egoing Lee', None, None, None, 1050, 27, 4.9, '2024-07-01 09:53:34')
# (143520, '해외취업 ASP.NET Core 웹개발 기본 강좌', 'SEJONG IT EDU', None, None, None, 1103, 74, 4.6, '2024-07-01 09:53:44')
# (145530, '빠르게 배우는 ES6 스킬과 자바스크립트 비동기 프로그래밍', '김형태', None, None, None, 218, 27, 4.5, '2024-07-01 09:53:53')
# (147672, '아이폰 앱 개발 입문 2편', '최완택', None, None, None, 2753, 108, 5.0, '2024-07-01 09:53:57')
# (149085, 'JSP 강의평가 웹 사이트 개발하기', '안경잡이개발자', None, None, None, 3091, 54, 4.1, '2024-07-01 09:54:01')
# (149177, '알고리즘의 개요와 실습 환경 구축', '안경잡이개발자', None, None, None, 2511, 24, 4.5, '2024-07-01 09:54:01')
# (149801, '모두를 위한 프로세스 마이닝', '이보경', None, None, None, 2237, 37, 4.7, '2024-07-01 09:53:57')
# (150560, '블록체인과 솔리디티', '박민 박', None, None, None, 4870, 176, 4.6, '2024-07-01 09:54:06')
# (151934, '견고한 JS 소프트웨어 만들기', '김정환', None, None, None, 1139, 90, 4.8, '2024-07-01 09:53:25')
# (152163, 'Javascript ES6+ 제대로 알아보기 - 초급', '정재남', None, None, None, 1642, 117, 4.9, '2024-07-01 09:53:00')
# (152374, "'내 생애 첫번째 코딩 앱인벤터' 저자에게 배우는 App Inventor", '이창현', None, None, None, 627, 14, 4.8, '2024-07-01 09:54:03')
# (153405, '블렌더(Blender)를 활용한 3D 캐릭터 애니메이션 만들기', 'gremaza', None, None, None, 67, 3, 1.3, '2024-07-01 09:53:57')
# (154639, '실무중심의 HTML5 시각화 프로그래밍', '트레이딩온', None, None, None, 34, 2, 3.5, '2024-07-01 09:54:01')
# (155470, '2D 캐드(CAD) 마스터하기 (오픈소프트웨어)', 'gremaza', None, None, None, 51, 3, 5.0, '2024-07-01 09:53:57')
# (155714, 'WEB2 - Node.js', 'Egoing Lee', None, None, None, 5622, 220, 4.9, '2024-07-01 09:53:34')
# (158906, '누구든지 하는 리액트: 초심자를 위한 react 핵심 강좌', 'velopert(김 민준)', None, None, None, 5544, 360, 4.7, '2024-07-01 09:53:53')
# (159719, '퍼블리셔 취업을 위해 제대로 배워보는 html과 css, 그리고 웹표준', 'Dongho Lee', None, None, None, 1502, 51, 4.7, '2024-07-01 09:53:47')
# (160163, 'OpenCV + WebApp (얼굴 눈 검출 웹앱만들기)', 'Jeonghyun Kim', None, None, None, 151, 11, 4.3, '2024-07-01 09:53:44')
# (165585, '파이썬 크롤링(Python Crawling)으로 웹 데이터 추출 입문부터 실습까지', 'Kyeongrok Kim', None, None, None, 98, 15, 4.5, '2024-07-01 09:54:03')
# (166833, '디지털 포렌식 (Digital Forensic) 전문가 과정', '보안프로젝트', None, None, None, 583, 49, 4.6, '2024-07-01 09:53:36')
# (167602, '디지털 포렌식 전문가 2급 실기 과정', '보안프로젝트', None, None, None, 520, 21, 4.6, '2024-07-01 09:53:16')
# (168717, '[김왼손의 왼손코딩] 한입에 쏙 파이썬: 3시간 만에 끝내는 파이썬 기초 (저자 직강)', '김왼손의 왼손코딩', None, None, None, 4369, 119, 4.7, '2024-07-01 09:53:54')
# (169847, 'MATLAB으로 시작하는 프로그래밍', '박범진', None, None, None, 3422, 99, 4.8, '2024-07-01 09:53:54')
# (169883, 'MAXST AR SDK와 유니티를 사용한 증강현실 앱 개발', 'MAXST 맥스트', None, None, None, 1996, 27, 4.7, '2024-07-01 09:54:03')
# (170706, '블록체인 기반의 스마트컨트랙트 개발', 'JeungJoo Lee', None, None, None, 356, 9, 4.2, '2024-07-01 09:53:42')
# (172458, 'IntelliJ를 시작하시는 분들을 위한 IntelliJ 가이드', '향로', None, None, None, 2291, 165, 4.7, '2024-07-01 09:52:53')
# (172546, '악성코드 분석 중급과정 (유형별분석)', '보안프로젝트', None, None, None, 518, 49, 4.4, '2024-07-01 09:53:16')
# (172836, '블록체인 이더리움 부동산 댑(Dapp) 만들기 - 기본편', 'SEJONG IT EDU', None, None, None, 718, 47, 4.5, '2024-07-01 09:53:25')
# (173707, 'PBR 리얼타임 캐릭터 제작', 'Sup Choi', None, None, None, 90, 5, 3.6, '2024-07-01 09:54:03')
# (174004, '객체 지향 프로그래밍 입문', '최범균', None, None, None, 2412, 231, 4.9, '2024-07-01 09:53:47')
# (176391, 'C# OpenCV 컴퓨터비전 입문 강좌', '윤대희', None, None, None, 360, 19, 4.8, '2024-07-01 09:53:47')
# (177843, '스프링 부트 개념과 활용', '백기선', None, None, None, 5342, 347, 4.8, '2024-07-01 09:53:02')
# (181289, '파이썬으로 구현하는 거래 자동화 봇 (챗봇)', 'Gunhee Lee', None, None, None, 241, 22, 4.5, '2024-07-01 09:53:53')
# (182303, '안드로이드 공식 언어 : 코틀린(Kotlin) 시작하기', 'Tae-hwan kwon', None, None, None, 183, 12, 4.1, '2024-07-01 09:53:53')
# (182737, '실전 JSP (renew ver.) - 신입 프로그래머를 위한 강좌', '인프런', None, None, None, 40713, 406, 4.6, '2024-07-01 09:53:08')
# (182835, '자바 프로그래밍 입문 강좌 (renew ver.) - 초보부터 개발자 취업까지!!', '인프런', None, None, None, 55528, 626, 4.7, '2024-07-01 09:53:14')
# (182992, '자바 스프링 프레임워크(renew ver.) - 신입 프로그래머를 위한 강좌', '인프런', None, None, None, 45045, 450, 4.7, '2024-07-01 09:53:14')
# (186343, '스프링 데이터 JPA', '백기선', None, None, None, 2458, 178, 4.8, '2024-07-01 09:53:18')
# (188224, '차트 기술분석 실전 매매 기법 Part1. 추세 활용 실전 매매 기법', '인베스트 크립토', None, None, None, 72, 6, 4.3, '2024-07-01 09:53:47')
# (189059, '김영삼의 모바일 앱 UX/UI 설계 및 디자인 실무', '소프트캠퍼스', None, None, None, 198, 10, 4.3, '2024-07-01 09:53:36')
# (189196, 'WEB2 Node.js-MySQL', 'Egoing Lee', None, None, None, 3608, 67, 4.9, '2024-07-01 09:53:47')
# (189600, '윤재성의 처음 시작하는 jQuery Programming', '소프트캠퍼스', None, None, None, 154, 14, 4.4, '2024-07-01 09:53:36')
# (191397, 'Node.js - Express', 'Egoing Lee', None, None, None, 3889, 48, 4.9, '2024-07-01 09:53:57')
# (191902, '윤재성의 처음시작하는 HTML & HTML5 Tutorials', '소프트캠퍼스', None, None, None, 101, 10, 4.7, '2024-07-01 09:53:30')
# (193153, 'Autocad 버전에 관계없이 완성하기', '이규태 (역지사지)', None, None, None, 53, 5, 5.0, '2024-07-01 09:53:47')
# (194516, 'Git과 GitHub 시작하기', '호눅스', None, None, None, 14400, 298, 4.8, '2024-07-01 09:53:53')
# (195597, '파이썬을 활용한 데이터분석과 IT보안', '보안프로젝트', None, None, None, 283, 25, 4.7, '2024-07-01 09:53:30')
# (197399, '윤재성의 Node.js 서버 프로그래밍 과정', '소프트캠퍼스', None, None, None, 207, 15, 4.5, '2024-07-01 09:53:36')
# (197776, '내 맥북을 자동화하기: 단순반복 작업이여 안녕', '홍영기', None, None, None, 99, 3, 3.3, '2024-07-01 09:53:53')
# (198715, '홍정모의 따라하며 배우는 C++', '홍정모', None, None, None, 6245, 297, 4.9, '2024-07-01 09:53:21')
# (201184, 'PWA 시작하기 - 웹 기술로 앱을 만들자', '장기효(캡틴판교)', None, None, None, 729, 29, 4.6, '2024-07-01 09:53:08')
# (201649, 'Unity 3D 장르별 실전 게임 프로젝트 - 디펜스게임', '소프트캠퍼스', None, None, None, 115, 4, 4.8, '2024-07-01 09:53:36')
# (204165, '3ds max Unwrap UVW 해부 강좌', '이규태 (역지사지)', None, None, None, 35, 0, 0.0, '2024-07-01 09:53:57')
# (204939, '강화학습 기초 이론', '팡요랩', None, None, None, 2339, 18, 4.9, '2024-07-01 09:54:03')
# (205127, 'Unity 3D 장르별 실전 게임 프로젝트- 클리커게임', '소프트캠퍼스', None, None, None, 135, 6, 5.0, '2024-07-01 09:53:22')
# (205574, '쉽고 빠르게 끝내는 GO언어 프로그래밍 핵심 기초 입문 과정', '좋은사람', None, None, None, 1285, 85, 4.7, '2024-07-01 09:53:12')
# (206638, '저작권 걱정없는 나만의 음악 만들기 - Studio One', '양승욱', None, None, None, 93, 4, 5.0, '2024-07-01 09:54:01')
# (210119, 'iOS AutoLayout 완벽 가이드 - 실무 프로젝트를 위한 실전강의', 'iOS Developer - 이정', None, None, None, 876, 63, 4.9, '2024-07-01 09:53:25')
# (211444, 'Electron과 NodeJS 그리고 Socket.io를 이용한 채팅 어플리케이션 개발', '김지운', None, None, None, 191, 9, 3.6, '2024-07-01 09:53:53')
# (211977, 'EOSJS를 이용한 EOS 심플 월렛 만들기', 'Dong Jun Kwon', None, None, None, 125, 12, 4.8, '2024-07-01 09:53:42')
# (212188, '윤재성의 Start Google Angular.js 앵귤러 과정', '소프트캠퍼스', None, None, None, 109, 6, 4.7, '2024-07-01 09:53:43')
# (212885, '윤재성의 Bootstrap 4 & 3 Framework Tutorial', '소프트캠퍼스', None, None, None, 239, 11, 4.7, '2024-07-01 09:53:30')
# (214582, "차트 기술분석 실전 매매 기법 Part2. '캔들'을 활용한 필승 매매", '인베스트 크립토', None, None, None, 37, 3, 5.0, '2024-07-01 09:53:53')
# (217043, "차트 기술분석 실전 매매 기법 Part3. '패턴'을 활용한 필승 매매 전략", '인베스트 크립토', None, None, None, 31, 1, 5.0, '2024-07-01 09:53:57')
# (217688, 'Javascript ES6+ 제대로 알아보기 - 중급', '정재남', None, None, None, 967, 45, 4.8, '2024-07-01 09:53:00')
# (218115, '유니티 강좌 [쯔꾸르풍 게임 제작하기]', '케이디', None, None, None, 4423, 24, 4.9, '2024-07-01 09:53:57')
# (218502, '트렐로 개발로 배우는 Vuejs, Vuex, Vue-Router 프론트엔드 실전 기술', '김정환', None, None, None, 1395, 83, 4.8, '2024-07-01 09:53:32')
# (219382, '스프링 프레임워크 핵심 기술', '백기선', None, None, None, 4594, 395, 4.8, '2024-07-01 09:52:58')
# (221292, '스프링 프레임워크 입문', '백기선', None, None, None, 15308, 448, 4.7, '2024-07-01 09:53:25')
# (221705, '윤재성의 처음시작하는 JavaScript Tutorials', '소프트캠퍼스', None, None, None, 133, 9, 4.3, '2024-07-01 09:53:43')
# (221839, '윤재성의 처음 시작하는 CSS & CSS3 Tutorials', '소프트캠퍼스', None, None, None, 855, 20, 4.7, '2024-07-01 09:53:43')
# (223277, 'HAL, CubeMX, TrueSTUDIO를 이용한 STM32F4 무료 강좌', 'ChrisP', None, None, None, 2909, 43, 5.0, '2024-07-01 09:54:01')
# (223482, '국내파들의 글로벌 커리어 개발', '유연실', None, None, None, 1443, 17, 4.9, '2024-07-01 09:53:57')
# (225314, '대회 문제 풀이로 이해하는 디스크 포렌식 분석', '보안프로젝트', None, None, None, 120, 8, 4.5, '2024-07-01 09:53:22')
# (226041, '윤재성의 처음 시작하는 MySQL DataBase', '소프트캠퍼스', None, None, None, 424, 31, 4.8, '2024-07-01 09:53:22')
# (228375, '윤재성의 처음 시작하는 파이썬', '소프트캠퍼스', None, None, None, 259, 30, 4.6, '2024-07-01 09:53:30')
# (228795, '윤재성의 처음 시작하는 C언어', '소프트캠퍼스', None, None, None, 2169, 36, 4.6, '2024-07-01 09:53:30')
# (231760, '[유니티 3D] 실전! 생존게임 만들기 - Advanced', '케이디', None, None, None, 802, 29, 4.8, '2024-07-01 09:53:57')
# (232177, '윤재성의 Oracle SQL Database 11g PL/SQL Developer', '소프트캠퍼스', None, None, None, 1048, 97, 4.6, '2024-07-01 09:53:36')
# (232452, '버전 관리 시스템 Git', 'Egoing Lee', None, None, None, 5304, 65, 4.9, '2024-07-01 09:53:34')
# (233723, '클라우드 서비스 AWS', 'Egoing Lee', None, None, None, 10318, 252, 4.9, '2024-07-01 09:53:21')
# (239083, "차트 기술분석 실전 매매 기법 Part4. '보조지표'를 활용한 필승 매매 A", '인베스트 크립토', None, None, None, 29, 1, 5.0, '2024-07-01 09:54:03')
# (239210, '공도리의 HTML5와 CSS3를 이용한 홈페이지 개발', '이우진', None, None, None, 3718, 82, 4.7, '2024-07-01 09:54:01')
# (239324, '[유니티 3D] FPS 서바이벌 디펜스', '케이디', None, None, None, 3209, 24, 4.8, '2024-07-01 09:53:57')
# (239527, '스프링 기반 REST API 개발', '백기선', None, None, None, 3399, 204, 4.7, '2024-07-01 09:52:58')
# (243067, '홍정모의 게임 만들기 연습 문제 패키지', '홍정모', None, None, None, 1196, 41, 4.7, '2024-07-01 09:53:34')
# (243266, '해킹 대회를 위한 시스템 해킹 프로토스타 완벽 풀이집', '보안프로젝트', None, None, None, 388, 25, 4.8, '2024-07-01 09:53:16')
# (246927, '맥으로 배우는 윈도우즈 포렌식', 'dorumugs', None, None, None, 56, 3, 2.7, '2024-07-01 09:53:47')
# (247815, '함수형 프로그래밍과 JavaScript ES6+', '유인동', None, None, None, 5193, 280, 4.9, '2024-07-01 09:52:59')
# (251181, '실전 자바 01 초보자 편', '이교준', None, None, None, 127, 17, 4.4, '2024-07-01 09:53:42')
# (256278, '엑셀 기초에서 실무까지', '짤막한 강좌(한정희)', None, None, None, 14537, 118, 4.9, '2024-07-01 09:53:47')
# (261836, '취미로 해킹#1(OverTheWire - Bandit)', '장용하', None, None, None, 861, 50, 4.7, '2024-07-01 09:53:25')
# (261984, '이더리움 입문 바이블: 모든 이더리움 입문자를 위하여', 'Mahesh', None, None, None, 4058, 264, 4.8, '2024-07-01 09:54:03')
# (262018, '이더리움 & 솔리디티 기반의 투표 dApp 구현하기', 'Mahesh', None, None, None, 2713, 41, 4.5, '2024-07-01 09:54:01')
# (262092, '탈중앙화 eBay 개발!: 실리콘밸리 개발자와 함께', 'Mahesh', None, None, None, 37, 1, 1.0, '2024-07-01 09:53:53')
# (262143, '트러플로 dApp 개발 : 실리콘밸리 개발자와 함께', 'Mahesh', None, None, None, 58, 1, 4.0, '2024-07-01 09:54:01')
# (262728, 'Vue.js 완벽 가이드 - 실습과 리팩토링으로 배우는 실전 개념', '장기효(캡틴판교)', None, None, None, 4656, 365, 4.9, '2024-07-01 09:53:08')
# (266104, "차트 기술분석 실전 매매 기법 Part4. '보조지표'를 활용한 필승 매매 B", '인베스트 크립토', None, None, None, 25, 1, 5.0, '2024-07-01 09:54:01')
# (269954, '선형대수학개론', '조범희 (타블렛깎는노인)', None, None, None, 2398, 89, 4.8, '2024-07-01 09:53:02')
# (274807, 'Swift로 함수형 프로그래밍 시작하기', '송치원', None, None, None, 147, 10, 4.5, '2024-07-01 09:53:47')
# (276507, '스크래치 코딩으로 배우는 수학의 개념과 원리', '노마드크리에이터', None, None, None, 1568, 16, 4.9, '2024-07-01 09:54:03')
# (277754, '스프링 웹 MVC', '백기선', None, None, None, 2495, 170, 4.9, '2024-07-01 09:53:12')
# (279337, '무작정 시작하는 안드로이드 개발', '노마드크리에이터', None, None, None, 2911, 23, 4.7, '2024-07-01 09:54:05')
# (279563, '게임으로 배우는 JavaScript', '노마드크리에이터', None, None, None, 2234, 13, 4.9, '2024-07-01 09:53:53')
# (280105, '나만의 포트폴리오 웹페이지 만들기', '시몬', None, None, None, 377, 21, 4.3, '2024-07-01 09:53:53')
# (283710, '[김왼손의 왼손코딩] 파이썬 예제 뽀개기: 파이썬 초중급자를 위한 파이썬 30제', '김왼손의 왼손코딩', None, None, None, 2586, 26, 4.8, '2024-07-01 09:54:02')
# (283958, '파이썬으로 장고(Django) 공략하기: 입문', '박순영', None, None, None, 912, 71, 4.6, '2024-07-01 09:53:27')
# (284646, '언리얼4 이펙터 추천! 블루프린트 이펙트 입문', '린반', None, None, None, 2140, 16, 4.4, '2024-07-01 09:53:54')
# (286212, '정보보안 및 개인정보보호 특강', '장용하', None, None, None, 4588, 434, 4.7, '2024-07-01 09:53:44')
# (286688, '공공데이터로 파이썬 데이터 분석 시작하기', '박조은', None, None, None, 5955, 306, 4.9, '2024-07-01 09:53:02')
# (287562, '쉽게 배워보는 파이참(PyCharm) 핵심 가이드', '좋은사람', None, None, None, 638, 51, 4.9, '2024-07-01 09:53:25')
# (287760, 'Flutter 입문 - 안드로이드, iOS 개발을 한 번에 (with Firebase)', '오준석', None, None, None, 2353, 190, 4.6, '2024-07-01 09:53:07')
# (288379, '리눅스 시스템 프로그래밍 - 이론과 실습', 'ProgCoach4U', None, None, None, 1358, 66, 4.8, '2024-07-01 09:53:27')
# (288444, '아두이노를 이용한 기상정보 수집과 빅데이터 분석', '노마드크리에이터', None, None, None, 1464, 25, 4.6, '2024-07-01 09:54:03')
# (290677, '디지털포렌식 분석 자격증 2급 필기 대비', '보안프로젝트', None, None, None, 375, 29, 4.1, '2024-07-01 09:53:36')
# (291285, '파이썬 프로그래밍', '블스', None, None, None, 6507, 107, 4.8, '2024-07-01 09:53:53')
# (292145, '2018 Do it! 안드로이드 앱 프로그래밍', '이지스퍼블리싱', None, None, None, 3544, 37, 4.7, '2024-07-01 09:53:49')
# (293650, '파이썬 라즈베리파이 IoT프로젝트-원격모니터링 자동차', '노마드크리에이터', None, None, None, 283, 17, 4.4, '2024-07-01 09:53:57')
# (295198, 'it 취업을 위한 알고리즘 문제풀이 입문 (with C/C++) : 코딩테스트 대비', '김태원', None, None, None, 3620, 139, 4.9, '2024-07-01 09:52:58')
# (296566, '스크래치 3.0 - 입문부터 실전 게임 개발까지', '나도코딩', None, None, None, 1687, 19, 4.9, '2024-07-01 09:53:57')
# (296828, '취미로 해킹#2(해커의 컴퓨팅)', '장용하', None, None, None, 1002, 42, 4.9, '2024-07-01 09:53:12')
# (299131, '공모전 사례로 풀어보는 앱 개발 프로젝트', '3G팀', None, None, None, 25, 4, 4.8, '2024-07-01 09:54:05')
# (303220, '윈도우 리버싱 (window reversing) 완벽 이해 - 레나 챌린지 풀이', '보안프로젝트', None, None, None, 382, 14, 4.6, '2024-07-01 09:53:43')
# (303962, 'Kevin의 알기 쉬운 Java 개발자 로드맵 이야기', 'Kevin', None, None, None, 3776, 123, 4.7, '2024-07-01 09:53:25')
# (305367, '프로세스 마이닝을 활용한 고객여정분석', '이보경', None, None, None, 1726, 28, 4.7, '2024-07-01 09:54:03')
# (305986, '카카오 김영삼 작가의 카톡 이모티콘 작가되기', '소프트캠퍼스', None, None, None, 115, 19, 4.9, '2024-07-01 09:53:30')
# (307599, '프로젝트를 통해 배우는 파이썬 프로그램', '노마드크리에이터', None, None, None, 3779, 17, 4.7, '2024-07-01 09:54:06')
# (309364, '파이썬을 활용한 선형대수학 - NumPy와 SciPy의 활용', '조범희 (타블렛깎는노인)', None, None, None, 551, 8, 5.0, '2024-07-01 09:53:07')
# (312168, 'Node.js로 웹 크롤링하기', '조현영', None, None, None, 857, 32, 4.8, '2024-07-01 09:53:31')
# (315347, '지금 당장 성과내기, 페이스북 퍼포먼스 마케팅 실습', 'Seongmin Yoo', None, None, None, 360, 29, 5.0, '2024-07-01 09:53:14')
# (318010, 'Vue.js - Django 연동 웹 프로그래밍', '김석훈', None, None, None, 649, 66, 4.6, '2024-07-01 09:53:23')
# (318520, '문제로 배우는 C언어', '김태원', None, None, None, 1367, 58, 4.9, '2024-07-01 09:53:02')
# (318646, 'Klaytn 클레이튼 블록체인 어플리케이션 만들기 - 이론과 실습', 'SEJONG IT EDU', None, None, None, 7330, 303, 4.8, '2024-07-01 09:53:44')
# (320594, '언리얼4 블루프린트로 안드로이드 게임 만들기', '린반', None, None, None, 216, 12, 4.6, '2024-07-01 09:53:23')
# (322115, 'iOS12 앱 개발 퍼펙트 가이드', 'iOS Developer - 이정', None, None, None, 379, 30, 4.8, '2024-07-01 09:53:32')
# (323991, 'JoyWins 큰돌샘의 아두이노 기초 강좌', '큰돌샘(JoyWins)', None, None, None, 672, 8, 4.9, '2024-07-01 09:54:03')
# (323992, '예제로 배우는 스프링 입문 (개정판)', '백기선', None, None, None, 24821, 652, 4.7, '2024-07-01 09:53:12')
# (324011, '벡터 미적분학 시리즈1 - 미분 기초', '조범희 (타블렛깎는노인)', None, None, None, 769, 19, 4.5, '2024-07-01 09:53:12')
# (324014, '리눅스 IPC 프로그래밍 - 이론과 실습', 'ProgCoach4U', None, None, None, 640, 19, 4.8, '2024-07-01 09:53:53')
# (324016, '코틀린으로 만드는 스프링부트', '최광성', None, None, None, 1942, 41, 3.5, '2024-07-01 09:54:06')
# (324018, '오픈소프트웨어 2.5D CNC 메이커캠 (Makercam) 강의', 'gremaza', None, None, None, 16, 3, 3.7, '2024-07-01 09:54:03')
# (324019, '함수형 프로그래밍과 JavaScript ES6+ 응용편', '유인동', None, None, None, 3145, 108, 4.9, '2024-07-01 09:53:03')
# (324024, '윤재성의 안드로이드를 위한 자바 프로그래밍', '소프트캠퍼스', None, None, None, 2065, 45, 4.6, '2024-07-01 09:53:36')
# (324026, '실전적용!! 아마존 셀러의 모든것', 'SmartAmazonSelling', None, None, None, 15, 0, 0.0, '2024-07-01 09:54:03')
# (324027, '윤재성의 만들면서 배우는 Spring MVC 5', '소프트캠퍼스', None, None, None, 861, 77, 4.9, '2024-07-01 09:53:22')
# (324030, '단 두 장의 문서로 데이터 분석과 시각화 뽀개기', '박조은', None, None, None, 2510, 167, 4.8, '2024-07-01 09:53:05')
# (324031, '코알못에서 웹서비스 런칭까지 : 2021 제주 코딩 베이스캠프(Django)', '제주코딩베이스캠프', None, None, None, 1251, 48, 4.7, '2024-07-01 09:53:16')
# (324032, 'Ethereum 실전! 초보자를 위한 Lottery Dapp 개발', 'dapp Campus', None, None, None, 2015, 44, 4.9, '2024-07-01 09:53:53')
# (324033, '인터랙티브 웹 개발 제대로 시작하기', '1분코딩', None, None, None, 3330, 298, 4.9, '2024-07-01 09:52:58')
# (324034, '겜팔이의 노릇노릇 파이어베이스', '겜팔이', None, None, None, 926, 12, 4.3, '2024-07-01 09:54:06')
# (324035, '취미로 해킹#3(WebGoat)', '장용하', None, None, None, 534, 20, 4.6, '2024-07-01 09:53:25')
# (324037, '남박사의 파이썬 기초부터 실전 100% 활용', '남박사', None, None, None, 2056, 105, 4.7, '2024-07-01 09:52:56')
# (324038, 'Angular(2+) Front에서 Back까지 - Nest js를 알려면 Angular 모듈을 알아야한다!', '앵귤러 개발자 김영태', None, None, None, 2623, 119, 4.9, '2024-07-01 09:53:57')
# (324039, 'iOS 개발을 위한 swift5 완벽 가이드', 'KxCoding', None, None, None, 438, 23, 4.7, '2024-07-01 09:53:30')
# (324041, '생활코딩 - React', 'Egoing Lee', None, None, None, 13011, 444, 4.9, '2024-07-01 09:53:47')
# (324042, '행정직을 위한 정시퇴근각 - 파이썬 업무자동화', 'kokori', None, None, None, 272, 11, 4.2, '2024-07-01 09:53:52')
# (324046, 'TDD 개발 방법론을 활용한 React Native 앱 개발', '박동호', None, None, None, 470, 51, 4.1, '2024-07-01 09:53:57')
# (324047, '챌린지로 알아보는 디지털포렌식 해킹 대회 준비 (기초)', '보안프로젝트', None, None, None, 220, 10, 4.9, '2024-07-01 09:53:36')
# (324048, '파이썬 레시피 - 웹 활용 입문편 (전자책 포함)', '반원', None, None, None, 3873, 41, 4.8, '2024-07-01 09:53:57')
# (324050, 'Flutter 초급 - Http통신, 상태관리', '오준석', None, None, None, 1172, 69, 4.7, '2024-07-01 09:53:38')
# (324052, '벡터 미적분학 시리즈2 - 미분 심화: 최적화 이론의 기초와 벡터 함수', '조범희 (타블렛깎는노인)', None, None, None, 510, 3, 5.0, '2024-07-01 09:53:31')
# (324056, '예제로 배우는 스프링부트 입문', '이재환', None, None, None, 691, 48, 4.5, '2024-07-01 09:53:52')
# (324059, '바닥부터 시작하는 STM32 드론 개발의 모든 것', 'ChrisP', None, None, None, 1409, 73, 5.0, '2024-07-01 09:53:27')
# (324061, '[애플 공식 교재] 스위프트 퍼즐 1', '코더스하이', None, None, None, 819, 7, 5.0, '2024-07-01 09:53:52')
# (324062, '[애플 공식 교재] iOS 앱 만들기 입문 (리뷰포함)', '코더스하이', None, None, None, 132, 19, 4.7, '2024-07-01 09:54:01')
# (324063, '웹 게임을 만들며 배우는 React', '조현영', None, None, None, 15626, 301, 4.9, '2024-07-01 09:53:30')
# (324065, 'Vue로 Nodebird SNS 만들기', '조현영', None, None, None, 620, 47, 4.8, '2024-07-01 09:53:30')
# (324066, 'R로 하는 웹 크롤링 - 입문편', '코코', None, None, None, 295, 28, 4.4, '2024-07-01 09:53:30')
# (324067, '파이썬으로 영화 예매 오픈 알리미 만들기', '한승우', None, None, None, 6562, 244, 4.9, '2024-07-01 09:53:53')
# (324068, '애프터이펙트를 시작해보자', 'jinlee982005', None, None, None, 89, 7, 5.0, '2024-07-01 09:54:01')
# (324069, '엑셀장인의 매크로', '엑셀장인', None, None, None, 181, 21, 4.4, '2024-07-01 09:54:01')
# (324071, '챌린지로 알아보는 디지털포렌식 해킹 대회 준비(심화)', '보안프로젝트', None, None, None, 102, 2, 5.0, '2024-07-01 09:53:43')
# (324072, '웹 서비스 해킹을 위한 버프스위트 완벽 활용 가이드', '보안프로젝트', None, None, None, 3898, 86, 4.8, '2024-07-01 09:53:43')
# (324075, 'Typescript with Vue 실전 프로젝트', '성도희', None, None, None, 552, 33, 4.5, '2024-07-01 09:54:03')
# (324078, '누구나 시작할 수 있는 네트워크 Step 1 (네트워크 모델)', '존찬', None, None, None, 411, 51, 3.7, '2024-07-01 09:53:58')
# (324081, '경영컨설팅 전문가 양성과정', 'bmc', None, None, None, 118, 12, 4.9, '2024-07-01 09:52:54')
# (324082, '파이썬입문과 크롤링기초 부트캠프 [파이썬, 웹, 데이터 이해 기본까지] (업데이트)', '잔재미코딩 DaveLee', None, None, None, 6038, 551, 4.9, '2024-07-01 09:52:54')
# (324088, 'Vue.js 시작하기 - Age of Vue.js', '장기효(캡틴판교)', None, None, None, 8756, 1406, 4.9, '2024-07-01 09:52:53')
# (324108, 'Angular, 앵귤러 100분 핵심강의', '노마드크리에이터', None, None, None, 87, 7, 3.9, '2024-07-01 09:54:03')
# (324109, '자바 ORM 표준 JPA 프로그래밍 - 기본편', '김영한', None, None, None, 20953, 1614, 5.0, '2024-07-01 09:52:54')
# (324111, '경영 컨설팅 전문가 양성과정 2 : 컨설팅 사례 및 해설 클리닉', 'bmc', None, None, None, 38, 2, 5.0, '2024-07-01 09:53:23')
# (324114, '윤재성의 Vue.js 프로젝트를 통한 실무 개발 과정', '소프트캠퍼스', None, None, None, 217, 13, 4.7, '2024-07-01 09:53:30')
# (324116, '인공지능 R GO! 하자!', '이수화', None, None, None, 2703, 34, 4.5, '2024-07-01 09:54:01')
# (324119, '실전! 스프링 부트와 JPA 활용1 - 웹 애플리케이션 개발', '김영한', None, None, None, 22734, 1967, 5.0, '2024-07-01 09:52:55')
# (324129, '[애플 공식 교재] iOS 앱 만들기 입문', '코더스하이', None, None, None, 396, 30, 4.8, '2024-07-01 09:54:01')
# (324131, '디자인 패턴 with JAVA (GoF)', '이재환', None, None, None, 964, 72, 4.4, '2024-07-01 09:53:34')
# (324134, '벡터 미적분학 시리즈3 - 적분 기초', '조범희 (타블렛깎는노인)', None, None, None, 397, 3, 5.0, '2024-07-01 09:53:31')
# (324135, '취미로 해킹#4(Nebula)', '장용하', None, None, None, 436, 15, 4.9, '2024-07-01 09:53:25')
# (324136, '[포토샵 혁명 방송] 포토샵 중급 완성', '유용한IT학습', None, None, None, 3631, 21, 4.9, '2024-07-01 09:53:43')
# (324137, 'IT보안을 위한 와이어샤크 네트워크 패킷 분석 실전', '보안프로젝트', None, None, None, 6405, 123, 4.8, '2024-07-01 09:53:43')
# (324138, 'SVG 마스터', '1분코딩', None, None, None, 1566, 89, 5.0, '2024-07-01 09:53:17')
# (324139, '자바 : 클래스의 이해와 객체지향 프로그래밍', '이재환', None, None, None, 1163, 131, 4.6, '2024-07-01 09:53:21')
# (324140, 'Web4 - Express-Session-Auth', 'Egoing Lee', None, None, None, 956, 12, 4.9, '2024-07-01 09:53:52')
# (324141, 'WEB5 - Express Passport.js', 'Egoing Lee', None, None, None, 949, 16, 5.0, '2024-07-01 09:53:47')
# (324144, '진짜 입문자를 위한 클라우드와 AWS', '호눅스', None, None, None, 1701, 288, 4.7, '2024-07-01 09:53:34')
# (324145, '프로그래밍 시작하기 : 파이썬 입문 (Inflearn Original)', '인프런', None, None, None, 30348, 888, 4.7, '2024-07-01 09:52:53')
# (324147, '누구나 할 수 있는 안드로이드 앱 개발 - 1 (Kotlin)', '개복치개발자', None, None, None, 332, 27, 3.9, '2024-07-01 09:53:48')
# (324148, '누구나 할 수 있는 안드로이드 앱 개발 - 2 (Kotlin)', '개복치개발자', None, None, None, 143, 8, 4.5, '2024-07-01 09:53:36')
# (324150, 'Vue, 뷰 100분 핵심강의', '노마드크리에이터', None, None, None, 73, 9, 4.7, '2024-07-01 09:54:05')
# (324151, '만들면서 배우는 HTML/CSS', '수코딩', None, None, None, 3695, 152, 4.8, '2024-07-01 09:54:05')
# (324152, '누구나 할 수 있다! 이모티콘 만들기', '소콘소콘', None, None, None, 8693, 109, 4.9, '2024-07-01 09:54:03')
# (324159, '코딩의민족 앱 제작 (Android kotlin)', '개복치개발자', None, None, None, 366, 21, 4.4, '2024-07-01 09:53:43')
# (324163, 'Swift로 iOS 2D 아케이드 게임 만들기', '냉동코더', None, None, None, 118, 8, 5.0, '2024-07-01 09:53:57')
# (324168, '파이썬 100분 핵심강의', '노마드크리에이터', None, None, None, 204, 17, 4.1, '2024-07-01 09:53:57')
# (324172, 'SwiftUI 초급 강의 - 기본 개념 익히기', 'Hohyeon Moon', None, None, None, 2880, 48, 4.7, '2024-07-01 09:53:52')
# (324174, 'Shiny 그리고 시각화 R Go! 하자!', '이수화', None, None, None, 1093, 20, 4.8, '2024-07-01 09:54:01')
# (324176, '스프링 시큐리티', '백기선', None, None, None, 1937, 132, 4.7, '2024-07-01 09:53:05')
# (324178, 'Database - SQL', '이교준', None, None, None, 674, 51, 4.7, '2024-07-01 09:53:34')
# (324179, '플랫폼 비즈니스 제대로 이해하기', '김재훈', None, None, None, 134, 19, 4.4, '2024-07-01 09:53:52')
# (324180, '프리다(Frida)를 이용한 안드로이드 앱 모의해킹', '보안프로젝트', None, None, None, 621, 31, 4.8, '2024-07-01 09:53:09')
# (324181, '노션(notion) 완벽 활용법', '보안프로젝트', None, None, None, 33228, 171, 4.8, '2024-07-01 09:53:30')
# (324182, '웹 게임을 만들며 배우는 Vue', '조현영', None, None, None, 7150, 129, 4.9, '2024-07-01 09:53:23')
# (324183, '처음하는 MongoDB(몽고DB) 와 NoSQL(빅데이터) 데이터베이스 부트캠프 [입문부터 활용까지] (업데이트)', '잔재미코딩 DaveLee', None, None, None, 2705, 147, 4.9, '2024-07-01 09:52:58')
# (324184, '더 자바, 코드를 조작하는 다양한 방법', '백기선', None, None, None, 4603, 300, 4.9, '2024-07-01 09:53:02')
# (324186, '데이터 시각화와 차트분석 기법', '노마드크리에이터', None, None, None, 3581, 48, 4.5, '2024-07-01 09:54:05')
# (324188, '데이터베이스 중급(Modeling)', '이교준', None, None, None, 1665, 124, 4.9, '2024-07-01 09:53:21')
# (324189, '파이썬 데이터시각화 분석 실전 프로젝트', '노마드크리에이터', None, None, None, 470, 25, 4.1, '2024-07-01 09:53:57')
# (324190, '대세는 쿠버네티스 [초급~중급]', '일프로', None, None, None, 6077, 410, 4.9, '2024-07-01 09:52:53')
# (324192, 'Java TPC (생각하고, 표현하고, 코딩하고)', '박매일', None, None, None, 2381, 224, 4.9, '2024-07-01 09:53:00')
# (324195, 'Unity 입문자를 위한 C프로그래밍 기초', 'SW School', None, None, None, 53, 2, 5.0, '2024-07-01 09:53:42')
# (324202, '워드프레스 제대로 개발하기 - 어드민 편', '워드프레스 개발', None, None, None, 475, 25, 4.9, '2024-07-01 09:53:42')
# (324207, '[텐서플로2] 파이썬 머신러닝 완전정복 - 마라톤 기록예측 프로젝트', '노마드크리에이터', None, None, None, 351, 25, 4.1, '2024-07-01 09:54:01')
# (324208, '처음하는 SQL과 데이터베이스(MySQL) 부트캠프 [입문부터 활용까지] (업데이트)', '잔재미코딩 DaveLee', None, None, None, 3348, 223, 4.8, '2024-07-01 09:53:00')
# (324209, '정보올림피아드(중등)', '가을', None, None, None, 116, 10, 5.0, '2024-07-01 09:53:34')
# (324211, '반드시 알아야 할 Tensorflow 수학', '최광성', None, None, None, 48, 2, 2.5, '2024-07-01 09:54:03')
# (324214, '실전! 스프링 부트와 JPA 활용2 - API 개발과 성능 최적화', '김영한', None, None, None, 17879, 1056, 5.0, '2024-07-01 09:52:56')
# (324215, 'Klaytn 클레이튼 블록체인 어플리케이션 만들기 - NFT', 'SEJONG IT EDU', None, None, None, 535, 41, 4.7, '2024-07-01 09:53:05')
# (324216, '2022 30분 요약 강좌 시즌 1 : HTML, CSS, Linux, Bootstrap, Python, JS,  jQuery&Ajax', '제주코딩베이스캠프', None, None, None, 11997, 133, 4.8, '2024-07-01 09:53:22')
# (324217, '일주일 만에 소프트웨어 요구사항 제대로 이해하기', 'SW School', None, None, None, 347, 47, 4.7, '2024-07-01 09:53:34')
# (324220, '지구에서 제일 쉽게 설명한 자료구조와 알고리즘', '개복치개발자', None, None, None, 366, 25, 4.5, '2024-07-01 09:53:36')
# (324223, '에펙 입문자도 만들 수 있는 유튜브 인트로 애프터이펙트 강좌', '쇼콜라떼', None, None, None, 187, 11, 4.9, '2024-07-01 09:53:27')
# (324224, '웹퍼블리셔가 알려주는 실무 웹사이트 따라만들기 Season1', '리베하얀', None, None, None, 4499, 95, 4.6, '2024-07-01 09:53:40')
# (324229, '코알못도 누구나 쉽게 따라하는 웹, 앱 만들기 (기초부터 실전 활용까지)', '조코딩', None, None, None, 3355, 76, 4.9, '2024-07-01 09:53:52')
# (324231, '케라스, 인공지능의 공용어 완전정복', '노마드크리에이터', None, None, None, 197, 10, 3.5, '2024-07-01 09:54:06')
# (324235, '자바스크립트 비기너: 튼튼한 기본 만들기', '김영보', None, None, None, 2119, 138, 4.7, '2024-07-01 09:53:54')
# (324236, '구글 알고리즘 문제 풀이', '최광성', None, None, None, 51, 1, 1.0, '2024-07-01 09:54:06')
# (324237, 'Swift 5와 SpriteKit으로 만들어보는 아이폰 iOS 2D 슈팅게임', '냉동코더', None, None, None, 57, 2, 5.0, '2024-07-01 09:54:03')
# (324238, '[개정판] 파이썬 머신러닝 완벽 가이드', '권 철민', None, None, None, 7254, 354, 4.9, '2024-07-01 09:52:54')
# (324264, '앵귤러 파이어베이스 완전정복 - PetStore 쇼핑몰 프로젝트', '노마드크리에이터', None, None, None, 53, 4, 3.0, '2024-07-01 09:53:57')
# (324265, '1:1채팅 만들기(Android + Kotlin + Firebase)', '개복치개발자', None, None, None, 254, 18, 3.9, '2024-07-01 09:53:36')
# (324268, '벡터 미적분학 시리즈4 - 적분 심화', '조범희 (타블렛깎는노인)', None, None, None, 363, 4, 5.0, '2024-07-01 09:53:38')
# (324279, '[입문] 예민한 UX 디자인', '전민수', None, None, None, 405, 21, 4.4, '2024-07-01 09:53:36')
# (324283, '제주코딩베이스캠프 Code Festival: Python 100제', '제주코딩베이스캠프', None, None, None, 1280, 22, 4.8, '2024-07-01 09:53:16')
# (324289, '자바 머신러닝 weka(웨카) 초급', '자바라머신러닝', None, None, None, 1871, 18, 4.9, '2024-07-01 09:54:01')
# (324290, 'Ionic, 아이오닉 100분 핵심강의', '노마드크리에이터', None, None, None, 922, 17, 4.4, '2024-07-01 09:54:01')
# (324292, '윤재성의 스프링 프레임워크 개발자를 위한 실습을 통한 입문 과정', '소프트캠퍼스', None, None, None, 767, 63, 4.7, '2024-07-01 09:53:16')
# (324298, '호주 현직 자바 개발자가 묻고 답하는 영어 기술면접 25', 'Jin Seo', None, None, None, 157, 17, 4.8, '2024-07-01 09:53:52')
# (324305, 'Java TPC 실전프로젝트 (Java API 활용)', '박매일', None, None, None, 982, 31, 4.7, '2024-07-01 09:53:36')
# (324314, '업무가 100배 빨라지는 엑셀 데이터 활용과 분석 노하우', '엑셀여신', None, None, None, 1715, 250, 4.9, '2024-07-01 09:53:12')
# (324318, '3dsmax 모델링 고수의 비밀! (Modeling Expert Technique)', '목마하임(MokmaHeim)', None, None, None, 446, 18, 5.0, '2024-07-01 09:53:21')
# (324331, '게임 개발을 위해 알아야 할 Azure CDN', '클라우드메이트', None, None, None, 1152, 14, 4.6, '2024-07-01 09:54:03')
# (324340, '태블로 레벨UP', 'VizLab', None, None, None, 2164, 33, 4.9, '2024-07-01 09:53:36')
# (324360, '언리얼 엔진4 (Unreal Engine) 3D 횡스크롤 게임 만들기', 'daehee Hwang', None, None, None, 390, 13, 4.4, '2024-07-01 09:53:54')
# (324376, '입문자를 위한 파이썬 기초 따라잡기', '보안프로젝트', None, None, None, 3469, 52, 4.9, '2024-07-01 09:53:30')
# (324379, '병.의원 경영컨설팅 실무 활용과정', 'bmc', None, None, None, 31, 1, 5.0, '2024-07-01 09:53:49')
# ...
# (333632, '셀프 성장법 이야기, Q&A 세션', '영화님 (와이노트 강영화)', None, None, None, 321, 2, 5.0, '2024-07-01 09:53:13')
# (333642, '데이터 사이언스 입문자를 위한 파이썬 및 통계', '부산대학교 소프트웨어융합교육원', None, None, None, 158, 0, 0.0, '2024-07-01 09:53:26')
# (333656, '게임기획자를 위한 강화학습 : AI 마리오 에이전트 키우기', '인공지능 교수 제이', None, None, None, 21, 0, 0.0, '2024-07-01 09:53:02')
# (333660, '데이터 분석을 위한 파이썬 입문', '부산대학교 소프트웨어융합교육원', None, None, None, 97, 0, 0.0, '2024-07-01 09:53:32')
# (333661, '머신러닝, 딥러닝 입문 : 알고리즘 이해하기', '부산대학교 소프트웨어융합교육원', None, None, None, 176, 3, 5.0, '2024-07-01 09:53:26')
# (333662, '문제해결을 통한 웹프로그래밍 입문', '부산대학교 소프트웨어융합교육원', None, None, None, 81, 0, 0.0, '2024-07-01 09:53:07')
# (333663, '처음 시작하는 MATLAB', '부산대학교 소프트웨어융합교육원', None, None, None, 64, 0, 0.0, '2024-07-01 09:53:07')
# (333664, '머신러닝, 딥러닝 기초 with Python, Keras', '부산대학교 소프트웨어융합교육원', None, None, None, 86, 0, 0.0, '2024-07-01 09:53:44')
# (333665, '피지컬 컴퓨팅을 위한 아두이노', '부산대학교 소프트웨어융합교육원', None, None, None, 58, 0, 0.0, '2024-07-01 09:53:26')
# (333666, 'Light Java - 제네릭, 람다식, 스트림편', '모모', None, None, None, 34, 2, 5.0, '2024-07-01 09:53:21')
# (333668, '[Python 초보] Flutter로 만드는 ChatGPT 음성번역앱', '다비', None, None, None, 56, 4, 5.0, '2024-07-01 09:53:03')
# (333670, '인생의 연봉을 가장 많이 올려주는 포트폴리오 강좌', '직장인 동물농장', None, None, None, 12, 3, 4.3, '2024-07-01 09:53:21')
# (333674, '시니어 개발자로 성장하기', 'Chaesang Jung', None, None, None, 14, 0, 0.0, '2024-07-01 09:53:03')
# (333680, '내 일상에 ChatGPT는 어떻게 활용되는가?', '태림 스튜디오', None, None, None, 101, 4, 4.8, '2024-07-01 09:53:34')
# (333681, 'LLM 데이터 분석 - 웹 크롤링부터 추천 시스템까지', '판다스 스튜디오', None, None, None, 43, 0, 0.0, '2024-07-01 09:53:03')
# (333682, 'Supabase, Next 풀 스택 시작하기 (feat. 슈파베이스 OAuth, nextjs 14)', '도도(코딩루팡)', None, None, None, 226, 8, 5.0, '2024-07-01 09:52:54')
# (333685, 'D3D12프로그래밍소개', 'megayuchi', None, None, None, 188, 5, 5.0, '2024-07-01 09:53:14')
# (333686, 'Godot Engine 으로 시작하는 첫 게임 개발', '코드쉼터', None, None, None, 726, 10, 5.0, '2024-07-01 09:52:58')
# (333687, '포트폴리오 사이트 만들고 배포까지! : 웹 개발 입문 활용편', '짐코딩', None, None, None, 24, 4, 5.0, '2024-07-01 09:52:56')
# (333689, '대용랑 채팅 TPS에 대한 stateful 서비스 구축하기', 'July', None, None, None, 169, 4, 4.8, '2024-07-01 09:52:58')
# (333701, '애플리케이션 배포 자동화와 CI/CD', '이준형(Foo)', None, None, None, 140, 0, 0.0, '2024-07-01 09:52:55')
# (333710, 'AI 시대에서 필요한 컴퓨팅 사고 방식 이해하기', 'Digital Spec Up', None, None, None, 4, 0, 0.0, '2024-07-01 09:53:20')
# (333720, '조직 문화를 탐험하며 디자인하기 (w. 이상효)', '인프런', None, None, None, 291, 0, 0.0, '2024-07-01 09:52:58')
# (333721, '[2024년] 지친 엑셀 유저를 위한 Power BI 기본 강의 (기초~중급 입문)', '어니언비아이', None, None, None, 6, 0, 0.0, '2024-07-01 09:53:03')
# (333723, '15가지 기법의 프롬프트 엔지니어링 (Prompt Engineering)', '배코블린', None, None, None, 80, 3, 4.7, '2024-07-01 09:53:07')
# (333724, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (0A) - 공개 샘플 강의', '드립커피+한모금더', None, None, None, 99, 4, 5.0, '2024-07-01 09:53:07')
# (333725, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (1) - 3D 그래픽스, OpenGL, 콜백 함수, 컬러 이론', '드립커피+한모금더', None, None, None, 162, 0, 0.0, '2024-07-01 09:52:56')
# (333726, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (2) - 프로그래머블 파이프라인, 기하학 기초, 삼각형 출력', '드립커피+한모금더', None, None, None, 129, 0, 0.0, '2024-07-01 09:52:56')
# (333727, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (3) - 애니메이션, depth 개념, Z 버퍼', '드립커피+한모금더', None, None, None, 113, 0, 0.0, '2024-07-01 09:53:02')
# (333728, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (4) - 좌표 변환, 회전, 가상 트랙볼', '드립커피+한모금더', None, None, None, 110, 0, 0.0, '2024-07-01 09:52:56')
# (333729, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (5) - 3D 카메라 뷰잉, 프로젝션, MVP 변환', '드립커피+한모금더', None, None, None, 102, 0, 0.0, '2024-07-01 09:52:56')
# (333730, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (6) - 쉐이딩 기초, 퐁 리플렉션 모델, 블린-퐁 쉐이딩', '드립커피+한모금더', None, None, None, 106, 0, 0.0, '2024-07-01 09:53:02')
# (333731, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (7) - 텍스처 매핑, 큐브 맵, 환경 매핑, 범프 매핑', '드립커피+한모금더', None, None, None, 99, 0, 0.0, '2024-07-01 09:53:02')
# (333734, '공식문서로 배우는 실전 타입스크립트', '어쩔코딩', None, None, None, 41, 0, 0.0, '2024-07-01 09:53:03')
# (333739, '실전! Django 활용', '신동현', None, None, None, 32, 0, 0.0, '2024-07-01 09:52:59')
# (333745, 'Real MySQL 시즌 1 - Part 2', '백은빈', None, None, None, 403, 0, 0.0, '2024-07-01 09:52:54')
# (333747, '3분만에 만드는 깃헙 블로그', '제주코딩베이스캠프', None, None, None, 291, 11, 5.0, '2024-07-01 09:53:27')
# (333754, '언리얼 엔진의 레벨 디자인과 시각화 표현(언리얼 그래픽스)', 'SW School', None, None, None, 12, 0, 0.0, '2024-07-01 09:53:02')
# (333757, '따라하면서 배우는 고박사의 유니티 하이퍼캐주얼게임 시리즈 04', '고박사', None, None, None, 22, 0, 0.0, '2024-07-01 09:53:08')
# (333758, 'D3D12 Mesh Shader소개', 'megayuchi', None, None, None, 98, 2, 5.0, '2024-07-01 09:53:21')
# (333764, '[최신]  1인 온라인마케팅 성공마스터 실무 교육', '나연재', None, None, None, 3, 0, 0.0, '2024-07-01 09:53:27')
# (333766, 'C++ 프로그래밍', '부산대학교 소프트웨어융합교육원', None, None, None, 147, 2, 5.0, '2024-07-01 09:53:13')
# (333770, '(2024) 일주일만에 합격하는 정보처리기사 실기', '주말코딩', None, None, None, 210, 6, 5.0, '2024-07-01 09:52:53')
# (333777, '시니어 개발자에서 매니저로: 새로운 도전과 성장', 'Chaesang Jung', None, None, None, 6, 0, 0.0, '2024-07-01 09:52:59')
# (333778, '두고두고 써먹는 유니티 비동기 프로그래밍', '오민석', None, None, None, 28, 0, 0.0, '2024-07-01 09:53:21')
# (333780, '엑셀로 만드는 딥러닝 - 분류', '멋진', None, None, None, 66, 0, 0.0, '2024-07-01 09:53:42')
# (333786, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (8) - 글로벌 일루미네이션, 블렌딩, 앤티-에일리어싱, 렌더 투 텍스처', '드립커피+한모금더', None, None, None, 24, 0, 0.0, '2024-07-01 09:52:56')
# (333787, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (9) - 스텐실, 커브&서피스, glTF', '드립커피+한모금더', None, None, None, 15, 0, 0.0, '2024-07-01 09:52:55')
# (333788, '게임 개발자를 위한 3D 그래픽스, 쉐이더, OpenGL (0B) - 공개 샘플 강의2', '드립커피+한모금더', None, None, None, 84, 5, 5.0, '2024-07-01 09:52:58')
# (333789, '하루만에 언리얼 엔진5 입문하기', 'Soft Story', None, None, None, 262, 2, 5.0, '2024-07-01 09:53:08')
# (333790, '타입스크립트로 배우는 동시성, 함수형 프로그래밍 (수요코딩회 ep.1)', '유인동', None, None, None, 320, 2, 5.0, '2024-07-01 09:53:13')
# (333791, '데이터 분석 및 EDA를 위한 파이썬 라이브러리', '나자바바', None, None, None, 49, 2, 5.0, '2024-07-01 09:53:07')
# (333792, '업무에 바로 활용하는 SSS급 일잘러를 위한 파이썬과 실습 작품들', '프로멘토', None, None, None, 6, 0, 0.0, '2024-07-01 09:53:02')
# (333793, '멀티패러다임 프로그래밍 언어 - 타입스크립트 (수요코딩회 ep.2 - 2.5)', '유인동', None, None, None, 235, 0, 0.0, '2024-07-01 09:53:26')
# (333794, '한번에 끝내는 컴퓨터활용능력 2급 필기 실기 종합 개정판', '컴티', None, None, None, 5, 0, 0.0, '2024-07-01 09:53:13')
# (333795, '[React / VanillaJS] UI 요소 직접 만들기 Part 2', '정재남', None, None, None, 161, 2, 5.0, '2024-07-01 09:53:03')
# (333796, 'RAG를 활용한 LLM Application 개발 (feat. LangChain)', '강병진', None, None, None, 11, 0, 0.0, '2024-07-01 09:52:53')
# (333799, '네트워크 비전공자의 이야기', 'CJCHO', None, None, None, 7, 3, 4.7, '2024-07-01 09:53:07')
# (333804, '자바 프로그래밍', '부산대학교 소프트웨어융합교육원', None, None, None, 90, 0, 0.0, '2024-07-01 09:53:39')
# (333805, 'Git과 GitHub 활용', '부산대학교 소프트웨어융합교육원', None, None, None, 149, 0, 0.0, '2024-07-01 09:53:32')
# (333806, '글로벌 매너와 커뮤니케이션', '부산대학교 소프트웨어융합교육원', None, None, None, 37, 0, 0.0, '2024-07-01 09:53:32')
# (333807, '비전공자도 이해할 수 있는 CI/CD 입문·실전', 'JSCODE 박재성', None, None, None, 607, 19, 4.9, '2024-07-01 09:52:56')
# (333808, 'Directx11을 이용한 게임 엔진 만들기', '얌얌코딩', None, None, None, 255, 2, 5.0, '2024-07-01 09:53:14')
# (333809, '스스로 프로그래밍 하는 기초 자료구조/알고리즘(C++)', '얌얌코딩', None, None, None, 248, 2, 5.0, '2024-07-01 09:53:27')
# (333810, 'AI 리터러시의 이해', '부산대학교 소프트웨어융합교육원', None, None, None, 58, 0, 0.0, '2024-07-01 09:53:32')
# (333813, '디지털 리터러시의 이해', '부산대학교 소프트웨어융합교육원', None, None, None, 29, 0, 0.0, '2024-07-01 09:53:26')
# (333820, '스케치업 프리 (Sketchup Free) 2024', '컴티', None, None, None, 2, 0, 0.0, '2024-07-01 09:53:13')
# (333828, 'Part2: 초중급 iOS 인스타그램 클론(SwiftUI, MVVM, Firebase, 2024)', '애구마(agmma)', None, None, None, 30, 3, 5.0, '2024-07-01 09:52:59')
# (333829, '폭발적인 조회수가 나오는 쇼츠 with 캡컷', '프로멘토', None, None, None, 85, 0, 0.0, '2024-07-01 09:53:02')
# (333830, 'DevOps를 위한 Docker 가상화 기술', 'Dowon Lee', None, None, None, 33, 0, 0.0, '2024-07-01 09:52:54')
# (333831, '인공신경망 딥러닝과 CNN', '나자바바', None, None, None, 21, 0, 0.0, '2024-07-01 09:53:13')
# (333839, '생성형 AI와 함께하는 데이터 분석가 커리어 [데이터리안 세미나 다시보기 | 2024년 5월]', '데이터리안', None, None, None, 57, 2, 5.0, '2024-07-01 09:53:14')
# (333843, '김일한의 리액트(React) 개발자를 위한 실습을 통한 입문 과정', '소프트캠퍼스', None, None, None, 9, 0, 0.0, '2024-07-01 09:53:21')
# (333849, '오라클 SQL 데이터베이스', '나자바바', None, None, None, 14, 0, 0.0, '2024-07-01 09:53:13')
# (333850, '세계 대회 진출자가 알려주는 코딩테스트 A to Z (with Python)', '알리 Ally', None, None, None, 110, 3, 5.0, '2024-07-01 09:52:58')
# (333851, 'LLM Application In Production', '그랩', None, None, None, 195, 0, 0.0, '2024-07-01 09:53:21')
# (333862, '초보 강사를 위한 AI 활용 가이드', '박형주', None, None, None, 3, 0, 0.0, '2024-07-01 09:52:59')
# (333864, '[빅데이터 러닝센터] (무료) KoreaPlus Statistics : 1편 Text Analytics', '빅데이터 러닝센터', None, None, None, 35, 0, 0.0, '2024-07-01 09:53:39')
# (333867, 'AI로 피그마에 날개 달기', '마소캠퍼스', None, None, None, 13, 0, 0.0, '2024-07-01 09:53:03')
# (333869, '(LLM개발) 랭체인과 챗GPT를 활용한 RAG 챗봇 만들기', '이진규', None, None, None, 26, 0, 0.0, '2024-07-01 09:53:20')
# (333877, '엑셀로 맛보는 딥러닝 -CNN', '멋진', None, None, None, 52, 0, 0.0, '2024-07-01 09:53:21')
# (333882, '데이터 리터러시의 이해', '부산대학교 소프트웨어융합교육원', None, None, None, 60, 0, 0.0, '2024-07-01 09:53:26')
# (333884, '창의적 프로그래밍', '부산대학교 소프트웨어융합교육원', None, None, None, 53, 0, 0.0, '2024-07-01 09:53:13')
# (333885, '앱 개발 입문자를 위한 플러터 네컷일기 만들기 with 피그마', 'Zero to One', None, None, None, 21, 0, 0.0, '2024-07-01 09:52:53')
# (333886, '비전공자도 쉽게 시작하는 증강현실(AR)로 나만의 고양이 만들기', 'Zero to One', None, None, None, 18, 0, 0.0, '2024-07-01 09:53:02')
# (333891, 'D3D12 프로그래밍-기초편', 'megayuchi', None, None, None, 28, 0, 0.0, '2024-07-01 09:53:03')
# (333899, 'D3D Tiled Resources를 이용한 텍스처 스트리밍', 'megayuchi', None, None, None, 59, 0, 0.0, '2024-07-01 09:53:14')
# (333909, '태블로 자격증 문제풀이', 'Gemma', None, None, None, 9, 0, 0.0, '2024-07-01 09:53:14')
# (333911, '백엔드 애플리케이션 성능 개선하기 - 기초편', '이준형(Foo)', None, None, None, 65, 0, 0.0, '2024-07-01 09:52:55')
# (333914, '200억건의 데이터를 MySQL로 마이그레이션 할 때 고려했던 개념과 튜닝 방법', 'July', None, None, None, 141, 5, 4.4, '2024-07-01 09:53:13')
# (333917, '코딩 테스트 합격자 되기 - C++', 'dremdeveloper', None, None, None, 260, 2, 5.0, '2024-07-01 09:53:34')
# (333919, '쉽게 배우는 해외인증 기초 - UL인증 편', '쉬운제품인증', None, None, None, 3, 0, 0.0, '2024-07-01 09:53:20')
# (333921, '데이터분석 입문', '부산대학교 소프트웨어융합교육원', None, None, None, 49, 0, 0.0, '2024-07-01 09:53:32')
# (333922, '데이터 마이닝', '부산대학교 소프트웨어융합교육원', None, None, None, 54, 0, 0.0, '2024-07-01 09:53:32')
# (333923, 'AI 이해를 위한 파이썬 기초', '부산대학교 소프트웨어융합교육원', None, None, None, 136, 0, 0.0, '2024-07-01 09:53:26')
# (333924, '코스페이시스 창의융합프로젝트 (Cospaces)', '부산대학교 소프트웨어융합교육원', None, None, None, 27, 0, 0.0, '2024-07-01 09:53:39')
# (333927, '[빅데이터 러닝센터] (무료) KoreaPlus Statistics : 2편 PSM', '빅데이터 러닝센터', None, None, None, 31, 0, 0.0, '2024-07-01 09:53:32')
# (333928, '[빅데이터 러닝센터] (무료) KNIME으로 시작하는 분석 Skill-Up', '빅데이터 러닝센터', None, None, None, 37, 0, 0.0, '2024-07-01 09:53:13')
# (333931, 'Real MySQL 시즌 1 - Part 1', '이성욱', None, None, None, 452, 4, 5.0, '2024-07-01 09:52:54')
# (333932, '[인프런] PM/PO 밋업 (with 김민우)', '인프런', None, None, None, 275, 0, 0.0, '2024-07-01 09:53:07')
# (333937, '[Rookiss 켠김에 출시까지] 유니티 캐주얼 모바일 MMORPG (M2)', 'Rookiss', None, None, None, 87, 0, 0.0, '2024-07-01 09:52:53')
# (333941, 'SignalR + ASP.NET Core [+MAUI +WPF]', '개발자Park', None, None, None, 23, 0, 0.0, '2024-07-01 09:53:07')
# (333944, '[빅데이터 러닝센터] (무료) 63, 64차 오픈하우스 - 효과크기와 검정력 분석 / 선형회귀의 확장과 진화', '빅데이터 러닝센터', None, None, None, 18, 0, 0.0, '2024-07-01 09:53:39')
# (333945, '블록으로 시작하는 코딩', '부산대학교 소프트웨어융합교육원', None, None, None, 25, 0, 0.0, '2024-07-01 09:53:13')
# (333946, '로봇과 함께 배우는 코딩', '부산대학교 소프트웨어융합교육원', None, None, None, 23, 0, 0.0, '2024-07-01 09:53:44')
# (333947, '틴커캐드로 만드는 3D 모델링  (Tinkercad)', '부산대학교 소프트웨어융합교육원', None, None, None, 28, 0, 0.0, '2024-07-01 09:53:20')
# (333948, '파이썬 백엔드 - gRPC: 개념부터  통신기법까지', '배코블린', None, None, None, 50, 0, 0.0, '2024-07-01 09:52:58')
# (333953, '스마트시트 사용하기 A to Z', '케이와이씨엠펌 최강프로', None, None, None, 4, 0, 0.0, '2024-07-01 09:53:13')
# (333954, '언리얼 네트워크', 'SW School', None, None, None, 11, 0, 0.0, '2024-07-01 09:53:02')
# (333958, 'Next.js 시작하기', '장기효(캡틴판교)', None, None, None, 248, 16, 4.8, '2024-07-01 09:52:55')
# (333964, '[빅데이터 러닝센터] (무료) 65, 66차 오픈하우스 - 점수화, 구간화, 최적 척도화 / 주변 효과와 부그룹 분석', '빅데이터 러닝센터', None, None, None, 19, 0, 0.0, '2024-07-01 09:53:39')
# (333969, '실리콘밸리에서 인정받는 개발자의 특징 (w. 한기용)', '인프런', None, None, None, 140, 4, 5.0, '2024-07-01 09:53:20')
# (333973, '내 업무를 위한 AI 비서 M365 코파일럿 활용 기본', '오마스', None, None, None, 7, 0, 0.0, '2024-07-01 09:53:07')
# (333979, '[매출과 수익성장이 쉬워지는] 실무재무강의', '재무선배', None, None, None, 7, 0, 0.0, '2024-07-01 09:53:02')
# (333984, '쉽게 설명하는 AWS 기초 강의', 'AWS 강의실', None, None, None, 130, 6, 5.0, '2024-07-01 09:52:53')
# (333985, '코딩이 처음인 초보자도 쉽게 만드는 파이썬 (Python) 으로 나만의 게임 만들기', 'Zero to One', None, None, None, 11, 2, 5.0, '2024-07-01 09:53:07')
# (333988, '실전 프론트엔드 테스트 시작하기', '장기효(캡틴판교)', None, None, None, 76, 0, 0.0, '2024-07-01 09:52:53')
# (333990, '워드프레스 홈페이지 & 블로그 제작으로 수익창출', '프로멘토', None, None, None, 3, 0, 0.0, '2024-07-01 09:52:53')
# (333998, '데이터 분석가 파헤치기(직무분석과 데이터와 관련된 직군까지!)', '컨티뉴언', None, None, None, 50, 0, 0.0, '2024-07-01 09:53:26')
# (334028, '우리 조직에 맞는 엔터프라이즈 LLM 도입과 활용 방안', '2e 컨설팅', None, None, None, 5, 0, 0.0, '2024-07-01 09:53:07')
# (334034, '[무료 파이썬]GPT에게 코딩을 맡기기 위한 코딩 강의', 'WonYoung Choi', None, None, None, 211, 3, 4.7, '2024-07-01 09:52:58')
# (334051, '11년 구하기, 전세사기-변호사 장고', '변호사 장고', None, None, None, 8, 0, 0.0, '2024-07-01 09:53:32')
# (334070, '앱 인벤터 창의융합프로젝트 (App Inventor)', '부산대학교 소프트웨어융합교육원', None, None, None, 26, 0, 0.0, '2024-07-01 09:53:39')
# (334080, '웹기획 코칭과정B_인턴형 PT :: 『금융 마이데이터 코디네이션』 분야', '미노플라넷', None, None, None, 3, 0, 0.0, '2024-07-01 09:53:13')
# (334082, '[2024]리베하얀의 HTML 기초 실무', '리베하얀', None, None, None, 3, 0, 0.0, '2024-07-01 09:53:13')
# (334083, '웹기획 응용과정B :: 『금융 마이데이터 코디네이션』 프로토타입 UI 기획 스킬', '미노플라넷', None, None, None, 2, 0, 0.0, '2024-07-01 09:53:02')
# (334084, '객체지향 프론트엔드 개발 & 타입스크립트 (수요코딩회 ep.3 - 5)', '유인동', None, None, None, 222, 0, 0.0, '2024-07-01 09:53:32')
# (334085, '비전공자도 이해할 수 있는 Docker 입문/실전', 'JSCODE 박재성', None, None, None, 170, 9, 5.0, '2024-07-01 09:52:55')
# (334087, '웹기획 코칭과정A_인턴형 PT :: 『빅데이터 플랫폼 프로젝트』 분야', '미노플라넷', None, None, None, 3, 0, 0.0, '2024-07-01 09:53:18')
# (334089, '새싹부터 시작하는 Unity 게임 개발', 'Pinous', None, None, None, 14, 0, 0.0, '2024-07-01 09:52:53')
# (334097, '[인프런] 강의 제작부터 홍보까지: 인프런과 함께하는 지식공유 여정', '인프런', None, None, None, 82, 0, 0.0, '2024-07-01 09:53:13')
# (334104, 'Amazing JavaScript - 입문', '장기효(캡틴판교)', None, None, None, 588, 7, 5.0, '2024-07-01 09:52:54')
# (334108, '노션 왕초보를 위한 렐레의 노션 AtoZ : 초급편', '렐레의 노션하우스', None, None, None, 3, 0, 0.0, '2024-07-01 09:53:18')
# (334113, '파이썬 기초, 이렇게 공부하면 정복가능하다.', '파이썬Master', None, None, None, 33, 0, 0.0, '2024-07-01 09:53:44')
# (334116, '오렌지3 창의융합프로젝트 (Orange3)', '부산대학교 소프트웨어융합교육원', None, None, None, 25, 0, 0.0, '2024-07-01 09:53:26')
# (334118, '마이크로비트&마퀸 창의융합프로젝트 (Microbit, Maqueen)', '부산대학교 소프트웨어융합교육원', None, None, None, 16, 0, 0.0, '2024-07-01 09:53:13')
# (334119, '아두이노 창의융합프로젝트 (Arduino)', '부산대학교 소프트웨어융합교육원', None, None, None, 26, 0, 0.0, '2024-07-01 09:53:13')
# (334121, '챗 GPT 크리에이트 (ChatGPT)', '부산대학교 소프트웨어융합교육원', None, None, None, 56, 0, 0.0, '2024-07-01 09:53:26')
# (334123, 'p5.js & ml5.js 창의융합프로젝트 (p5.js & ml5.js)', '부산대학교 소프트웨어융합교육원', None, None, None, 36, 0, 0.0, '2024-07-01 09:53:26')
# (334124, '마이크로파이썬 창의융합프로젝트 (MicroPython)', '부산대학교 소프트웨어융합교육원', None, None, None, 26, 0, 0.0, '2024-07-01 09:53:26')
# (334128, '단어로 배우는 중국어 회화 2탄', '하루배움 중국어', None, None, None, 27, 0, 0.0, '2024-07-01 09:53:13')
# (334133, '모르면 승진 안되는 시스템 디자인', '실리콘밸리 아저씨들', None, None, None, 35, 0, 0.0, '2024-07-01 09:52:53')
# (334173, '데이터기반 스토리텔링', '부산대학교 소프트웨어융합교육원', None, None, None, 24, 0, 0.0, '2024-07-01 09:53:13')
# (334174, '정보와 데이터 사이언스를 위한 프로젝트 관리', '부산대학교 소프트웨어융합교육원', None, None, None, 23, 0, 0.0, '2024-07-01 09:53:07')
# (334175, '빅데이터 기반 정책평가론', '부산대학교 소프트웨어융합교육원', None, None, None, 23, 0, 0.0, '2024-07-01 09:53:13')
# (334204, '리베하얀의 CSS3 기초실무 - 2024', '리베하얀', None, None, None, 3, 0, 0.0, '2024-07-01 09:52:54')
# (334232, '쉽게 배우는 국내인증 기초 - KC, KCS, KS인증 편', '쉬운제품인증', None, None, None, 2, 0, 0.0, '2024-07-01 09:53:02')
# (334235, 'B2B 마케팅을 위한 링크드인 200% 활용법 (세미나 다시보기)', 'Grace Shin', None, None, None, 4, 0, 0.0, '2024-07-01 09:52:54')
# 총 3457개의 강의가 저장되어 있습니다.
