# %%
# !pip install html5lib
# !pip install lxml
# !pip install beautifulSoup4

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
url = "https://search.shopping.naver.com/catalog/24249545535?cat_id=50001768"
# url = "https://search.shopping.naver.com/catalog/21098473707"
print(url)
# Out:
# https://search.shopping.naver.com/catalog/24249545535?cat_id=50001768

# %%
response = requests.get(url)
review = []
# 응답의 상태코드를 확인합니다. 200은 성공을 의미합니다.
if response.status_code == 200:
    # BeautifulSoup 객체를 생성합니다.
    soup = bs(response.text)
    li_list = soup.select("#section_review > ul > li")
    for li in li_list:
        review.append(li.text)
else:
    # 응답이 실패한 경우, 상태코드를 출력합니다.
    print("Error: ", response.status_code)

# %%
len(review)
# Out:
# 20

# %%
df = pd.DataFrame(review, columns=["review"])
df["star"] = df["review"].str[:3].str.replace("평점", "").astype(int)
df["review_text"] = df["review"].str[3:]
df
# Out:
#                                                review  star  \
# 0   평점5컬럼비아 영통점mach****22.12.20.색상: 여성-베이지(271) / ...     5
# 1   평점4컬럼비아 영통점nice****22.06.22.색상: 여성-베이지(271) / ...     4
# 2   평점5컬럼비아 영통점ny17****21.02.09.컬러: 베이지(271) / 사이즈...     5
# 3   평점5컬럼비아 영통점seob****21.02.21.컬러: 베이지(271) / 사이즈...     5
# 4   평점5컬럼비아 영통점bmjs****21.08.19.컬러: 베이지(271) / 사이즈...     5
# 5   평점5컬럼비아 영통점1522****20.09.08.컬러: 브라운(227) / 사이즈...     5
# 6   평점5컬럼비아 영통점unic****21.02.09.컬러: 베이지(271) / 사이즈...     5
# 7   평점5컬럼비아 무등산점alsw****21.02.20.컬러: 베이지(227) / 사이...     5
# 8   평점5컬럼비아스포츠웨어msch****21.10.12.사이즈: 240디자인도 마음에 ...     5
# 9   평점5컬럼비아 무등산점gora****21.12.23.컬러: 그레이(005) / 사이...     5
# 10  평점5suav****21.07.31.색상: 271 / 사이즈: 245상품평 참고 및...     5
# 11  평점5컬럼비아 영통점jota****22.12.16.색상: 남성-베이지(241) / ...     5
# 12  평점5제로나인 리테일lege****23.04.21.색상: 베이지 / 사이즈: 235...     5
# 13  평점5컬럼비아 영통점bono****21.01.31.컬러: 베이지(271) / 사이즈...     5
# 14  평점5컬럼비아 영통점apha****21.02.09.컬러: 베이지(271) / 사이즈...     5
# 15  평점5컬럼비아 무등산점kifu****21.03.06.컬러: 연베이지(271) / 사...     5
# 16  평점5컬럼비아 영통점rami****21.03.03.컬러: 브라운(227) / 사이즈...     5
# 17  평점5컬럼비아 영통점miya****23.01.11.색상: 남성-베이지(241) / ...     5
# 18  평점5컬럼비아 영통점a900****21.04.26.컬러: 브라운(227) / 사이즈...     5
# 19  평점4컬럼비아 영통점smil****21.02.24.컬러: 브라운(227) / 사이즈...     4
#
#                                           review_text
# 0   컬럼비아 영통점mach****22.12.20.색상: 여성-베이지(271) / 사이즈...
# 1   컬럼비아 영통점nice****22.06.22.색상: 여성-베이지(271) / 사이즈...
# 2   컬럼비아 영통점ny17****21.02.09.컬러: 베이지(271) / 사이즈: 2...
# 3   컬럼비아 영통점seob****21.02.21.컬러: 베이지(271) / 사이즈: 2...
# 4   컬럼비아 영통점bmjs****21.08.19.컬러: 베이지(271) / 사이즈: 2...
# 5   컬럼비아 영통점1522****20.09.08.컬러: 브라운(227) / 사이즈: 2...
# 6   컬럼비아 영통점unic****21.02.09.컬러: 베이지(271) / 사이즈: 2...
# 7   컬럼비아 무등산점alsw****21.02.20.컬러: 베이지(227) / 사이즈: ...
# 8   컬럼비아스포츠웨어msch****21.10.12.사이즈: 240디자인도 마음에 들고 ...
# 9   컬럼비아 무등산점gora****21.12.23.컬러: 그레이(005) / 사이즈: ...
# 10  suav****21.07.31.색상: 271 / 사이즈: 245상품평 참고 및 두꺼...
# 11  컬럼비아 영통점jota****22.12.16.색상: 남성-베이지(241) / 사이즈...
# 12  제로나인 리테일lege****23.04.21.색상: 베이지 / 사이즈: 235건강을...
# 13  컬럼비아 영통점bono****21.01.31.컬러: 베이지(271) / 사이즈: 2...
# 14  컬럼비아 영통점apha****21.02.09.컬러: 베이지(271) / 사이즈: 2...
# 15  컬럼비아 무등산점kifu****21.03.06.컬러: 연베이지(271) / 사이즈:...
# 16  컬럼비아 영통점rami****21.03.03.컬러: 브라운(227) / 사이즈: 2...
# 17  컬럼비아 영통점miya****23.01.11.색상: 남성-베이지(241) / 사이즈...
# 18  컬럼비아 영통점a900****21.04.26.컬러: 브라운(227) / 사이즈: 2...
# 19  컬럼비아 영통점smil****21.02.24.컬러: 브라운(227) / 사이즈: 2...

# %%
import networkx as nx
from collections import Counter
import re

# 텍스트 데이터에서 단어를 추출합니다.
text = review[0].split("포토리뷰")[0]
text = re.sub("[0-9]", "", text)
words = text.lower().split()

# 각 단어의 빈도수를 계산합니다.
word_counts = Counter(words)

# 단어 간의 연결을 만듭니다.
edges = [(w1, w2, {'weight': count}) for w1, count1 in word_counts.items() 
         for w2, count2 in word_counts.items() 
         for count in [len(set(w1) & set(w2))] if count > 0 and w1 != w2]

# 네트워크 그래프를 생성합니다.
G = nx.Graph()

# 그래프에 노드와 엣지를 추가합니다.
for word, count in word_counts.items():
    G.add_node(word, count=count)
for edge in edges:
    G.add_edge(*edge[:2], **edge[2])

# 그래프에서 중심성 계산을 수행합니다.
degree_centrality = nx.degree_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)

# 중심성 값을 출력합니다.
for word in word_counts:
    print(f"{word}: degree centrality={degree_centrality[word]:.3f}, closeness centrality={closeness_centrality[word]:.3f}, betweenness centrality={betweenness_centrality[word]:.3f}")
# Out:
# 평점컬럼비아: degree centrality=0.055, closeness centrality=0.311, betweenness centrality=0.017
# 영통점mach****...색상:: degree centrality=0.031, closeness centrality=0.295, betweenness centrality=0.008
# 여성-베이지(): degree centrality=0.141, closeness centrality=0.351, betweenness centrality=0.078
# /: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 사이즈:: degree centrality=0.098, closeness centrality=0.337, betweenness centrality=0.008
# 생각: degree centrality=0.006, closeness centrality=0.008, betweenness centrality=0.000
# 했던: degree centrality=0.012, closeness centrality=0.238, betweenness centrality=0.000
# 것: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 보다: degree centrality=0.074, closeness centrality=0.281, betweenness centrality=0.010
# 견고하고: degree centrality=0.086, closeness centrality=0.317, betweenness centrality=0.007
# 투박하지: degree centrality=0.086, closeness centrality=0.321, betweenness centrality=0.011
# 않고: degree centrality=0.043, closeness centrality=0.257, betweenness centrality=0.000
# 아주: degree centrality=0.061, closeness centrality=0.319, betweenness centrality=0.031
# 더운: degree centrality=0.025, closeness centrality=0.258, betweenness centrality=0.006
# 계절이: degree centrality=0.086, closeness centrality=0.325, betweenness centrality=0.000
# 아니면: degree centrality=0.086, closeness centrality=0.355, betweenness centrality=0.038
# 자주: degree centrality=0.025, closeness centrality=0.250, betweenness centrality=0.021
# 신고: degree centrality=0.092, closeness centrality=0.329, betweenness centrality=0.017
# 다닐: degree centrality=0.055, closeness centrality=0.276, betweenness centrality=0.000
# 수: degree centrality=0.012, closeness centrality=0.220, betweenness centrality=0.000
# 있을: degree centrality=0.061, closeness centrality=0.287, betweenness centrality=0.015
# 만큼: degree centrality=0.012, closeness centrality=0.250, betweenness centrality=0.000
# 너무: degree centrality=0.018, closeness centrality=0.215, betweenness centrality=0.000
# 맘에: degree centrality=0.018, closeness centrality=0.219, betweenness centrality=0.000
# 듭니다.: degree centrality=0.080, closeness centrality=0.313, betweenness centrality=0.017
# 제: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 돈: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 주고: degree centrality=0.061, closeness centrality=0.272, betweenness centrality=0.008
# 처음: degree centrality=0.006, closeness centrality=0.006, betweenness centrality=0.000
# 산: degree centrality=0.012, closeness centrality=0.232, betweenness centrality=0.000
# 거라: degree centrality=0.031, closeness centrality=0.284, betweenness centrality=0.006
# 판매자님께: degree centrality=0.012, closeness centrality=0.194, betweenness centrality=0.010
# 문의: degree centrality=0.025, closeness centrality=0.261, betweenness centrality=0.006
# 하기도: degree centrality=0.123, closeness centrality=0.367, betweenness centrality=0.066
# 했는: degree centrality=0.074, closeness centrality=0.293, betweenness centrality=0.006
# 데생각: degree centrality=0.012, closeness centrality=0.012, betweenness centrality=0.000
# 데: degree centrality=0.006, closeness centrality=0.008, betweenness centrality=0.000
# 정도: degree centrality=0.049, closeness centrality=0.294, betweenness centrality=0.000
# 크게: degree centrality=0.018, closeness centrality=0.206, betweenness centrality=0.000
# 주문: degree centrality=0.031, closeness centrality=0.268, betweenness centrality=0.009
# 하래서: degree centrality=0.092, closeness centrality=0.334, betweenness centrality=0.014
# 했더니: degree centrality=0.049, closeness centrality=0.298, betweenness centrality=0.010
# 정도치수: degree centrality=0.061, closeness centrality=0.296, betweenness centrality=0.021
# 높여: degree centrality=0.018, closeness centrality=0.268, betweenness centrality=0.000
# 사도: degree centrality=0.067, closeness centrality=0.314, betweenness centrality=0.006
# 좋을: degree centrality=0.055, closeness centrality=0.265, betweenness centrality=0.003
# 같아요: degree centrality=0.092, closeness centrality=0.338, betweenness centrality=0.010
# 작게: degree centrality=0.018, closeness centrality=0.206, betweenness centrality=0.000
# 나온: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 평소: degree centrality=0.006, closeness centrality=0.228, betweenness centrality=0.000
# 운동화: degree centrality=0.012, closeness centrality=0.215, betweenness centrality=0.000
# 브랜드마다: degree centrality=0.074, closeness centrality=0.288, betweenness centrality=0.038
# 사이즈가: degree centrality=0.098, closeness centrality=0.335, betweenness centrality=0.007
# 다른: degree centrality=0.055, closeness centrality=0.276, betweenness centrality=0.000
# 보통~: degree centrality=0.037, closeness centrality=0.284, betweenness centrality=0.011
# 신거든요: degree centrality=0.110, closeness centrality=0.341, betweenness centrality=0.012
# 한: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 신발은: degree centrality=0.092, closeness centrality=0.340, betweenness centrality=0.013
# 끈을: degree centrality=0.043, closeness centrality=0.248, betweenness centrality=0.000
# 풀지: degree centrality=0.037, closeness centrality=0.274, betweenness centrality=0.000
# 신어서: degree centrality=0.104, closeness centrality=0.340, betweenness centrality=0.021
# 인지: degree centrality=0.037, closeness centrality=0.274, betweenness centrality=0.000
# 꽉: degree centrality=0.006, closeness centrality=0.254, betweenness centrality=0.000
# 조이는: degree centrality=0.135, closeness centrality=0.354, betweenness centrality=0.017
# 느낌이: degree centrality=0.086, closeness centrality=0.325, betweenness centrality=0.000
# 드네요: degree centrality=0.055, closeness centrality=0.314, betweenness centrality=0.016
# 새끼: degree centrality=0.018, closeness centrality=0.216, betweenness centrality=0.000
# 발가락이: degree centrality=0.135, closeness centrality=0.362, betweenness centrality=0.031
# 신발: degree centrality=0.080, closeness centrality=0.336, betweenness centrality=0.004
# 앞: degree centrality=0.006, closeness centrality=0.173, betweenness centrality=0.000
# 코에서: degree centrality=0.061, closeness centrality=0.282, betweenness centrality=0.023
# 꽉~차이는: degree centrality=0.147, closeness centrality=0.360, betweenness centrality=0.044
# ㅎ: degree centrality=0.006, closeness centrality=0.006, betweenness centrality=0.000
# 하면: degree centrality=0.067, closeness centrality=0.320, betweenness centrality=0.003
# 꼼지락: degree centrality=0.043, closeness centrality=0.288, betweenness centrality=0.002
# 거려도: degree centrality=0.074, closeness centrality=0.314, betweenness centrality=0.005
# 될: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 듯^^보내: degree centrality=0.043, closeness centrality=0.245, betweenness centrality=0.025
# 준: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 양말을: degree centrality=0.043, closeness centrality=0.248, betweenness centrality=0.000
# 신었더니: degree centrality=0.092, closeness centrality=0.358, betweenness centrality=0.040
# 내: degree centrality=0.006, closeness centrality=0.191, betweenness centrality=0.000
# 발이: degree centrality=0.123, closeness centrality=0.358, betweenness centrality=0.016
# 찬: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 느낌이었는: degree centrality=0.141, closeness centrality=0.356, betweenness centrality=0.020
# 여유롭게: degree centrality=0.037, closeness centrality=0.270, betweenness centrality=0.031
# 하고: degree centrality=0.086, closeness centrality=0.317, betweenness centrality=0.007
# 방: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 안에서만: degree centrality=0.061, closeness centrality=0.290, betweenness centrality=0.017
# 빙그르르: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 돌고: degree centrality=0.049, closeness centrality=0.266, betweenness centrality=0.002
# 돌았네요: degree centrality=0.055, closeness centrality=0.302, betweenness centrality=0.003
# 쿠션감은: degree centrality=0.031, closeness centrality=0.292, betweenness centrality=0.002
# 덜: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 하지만: degree centrality=0.098, closeness centrality=0.325, betweenness centrality=0.025
# 발목을: degree centrality=0.086, closeness centrality=0.302, betweenness centrality=0.024
# 감싸는: degree centrality=0.080, closeness centrality=0.300, betweenness centrality=0.007
# 좋아요: degree centrality=0.098, closeness centrality=0.340, betweenness centrality=0.017
# 무엇보다: degree centrality=0.092, closeness centrality=0.284, betweenness centrality=0.042
# 발바닥의: degree centrality=0.061, closeness centrality=0.309, betweenness centrality=0.019
# 피로감이: degree centrality=0.104, closeness centrality=0.335, betweenness centrality=0.006
# 없고: degree centrality=0.043, closeness centrality=0.257, betweenness centrality=0.000
# 편해서: degree centrality=0.049, closeness centrality=0.282, betweenness centrality=0.011
# 벗는: degree centrality=0.061, closeness centrality=0.290, betweenness centrality=0.000
# 게: degree centrality=0.018, closeness centrality=0.206, betweenness centrality=0.000
# 무리: degree centrality=0.025, closeness centrality=0.216, betweenness centrality=0.000
# ,무리일: degree centrality=0.037, closeness centrality=0.216, betweenness centrality=0.021
# 듯: degree centrality=0.006, closeness centrality=0.191, betweenness centrality=0.000
# !: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 보통: degree centrality=0.031, closeness centrality=0.242, betweenness centrality=0.001
# 새: degree centrality=0.018, closeness centrality=0.216, betweenness centrality=0.000
# 신으면: degree centrality=0.061, closeness centrality=0.321, betweenness centrality=0.001
# 발: degree centrality=0.043, closeness centrality=0.294, betweenness centrality=0.000
# 치수: degree centrality=0.012, closeness centrality=0.220, betweenness centrality=0.000
# 맞는: degree centrality=0.061, closeness centrality=0.290, betweenness centrality=0.000
# 바닥이: degree centrality=0.092, closeness centrality=0.327, betweenness centrality=0.002
# 딱딱해: degree centrality=0.006, closeness centrality=0.212, betweenness centrality=0.000
# 서: degree centrality=0.037, closeness centrality=0.278, betweenness centrality=0.000
# 잠깐: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 있어도: degree centrality=0.086, closeness centrality=0.327, betweenness centrality=0.014
# 불편하고: degree centrality=0.092, closeness centrality=0.319, betweenness centrality=0.010
# 다리: degree centrality=0.067, closeness centrality=0.278, betweenness centrality=0.018
# 피로감도: degree centrality=0.067, closeness centrality=0.313, betweenness centrality=0.006
# 와: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 닿는: degree centrality=0.061, closeness centrality=0.290, betweenness centrality=0.000
# 이: degree centrality=0.086, closeness centrality=0.325, betweenness centrality=0.000
# 하루: degree centrality=0.055, closeness centrality=0.308, betweenness centrality=0.000
# 종일: degree centrality=0.012, closeness centrality=0.173, betweenness centrality=0.000
# 괜찮을: degree centrality=0.043, closeness centrality=0.248, betweenness centrality=0.000
# 좋은: degree centrality=0.025, closeness centrality=0.270, betweenness centrality=0.001
# 신발같아서: degree centrality=0.160, closeness centrality=0.369, betweenness centrality=0.078
# 부모님: degree centrality=0.006, closeness centrality=0.158, betweenness centrality=0.000
# 이사하신: degree centrality=0.196, closeness centrality=0.381, betweenness centrality=0.059
# 집: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 근처: degree centrality=0.006, closeness centrality=0.006, betweenness centrality=0.000
# 문경새재관문까지: degree centrality=0.067, closeness centrality=0.286, betweenness centrality=0.040
# 새벽: degree centrality=0.018, closeness centrality=0.216, betweenness centrality=0.000
# 공기: degree centrality=0.018, closeness centrality=0.285, betweenness centrality=0.000
# 마시며: degree centrality=0.012, closeness centrality=0.216, betweenness centrality=0.000
# 걸어도: degree centrality=0.067, closeness centrality=0.309, betweenness centrality=0.003
# 싶어요: degree centrality=0.067, closeness centrality=0.313, betweenness centrality=0.002
# 다니기: degree centrality=0.092, closeness centrality=0.342, betweenness centrality=0.064
# 코스라: degree centrality=0.018, closeness centrality=0.232, betweenness centrality=0.001
# 가벼운: degree centrality=0.025, closeness centrality=0.265, betweenness centrality=0.007
# 산책삼아: degree centrality=0.055, closeness centrality=0.309, betweenness centrality=0.013
# 되는: degree centrality=0.061, closeness centrality=0.290, betweenness centrality=0.000
# 곳이거든요: degree centrality=0.147, closeness centrality=0.361, betweenness centrality=0.036
# ㅎㅎㅎ: degree centrality=0.006, closeness centrality=0.006, betweenness centrality=0.000
# 산을: degree centrality=0.055, closeness centrality=0.258, betweenness centrality=0.003
# 다니는: degree centrality=0.135, closeness centrality=0.345, betweenness centrality=0.063
# 분들에겐: degree centrality=0.018, closeness centrality=0.219, betweenness centrality=0.000
# 앞마당: degree centrality=0.018, closeness centrality=0.217, betweenness centrality=0.010
# 같을: degree centrality=0.055, closeness centrality=0.280, betweenness centrality=0.006
# 있는: degree centrality=0.080, closeness centrality=0.320, betweenness centrality=0.017
# 코스: degree centrality=0.012, closeness centrality=0.214, betweenness centrality=0.000
# 일: degree centrality=0.012, closeness centrality=0.173, betweenness centrality=0.000
# 저: degree centrality=0.006, closeness centrality=0.228, betweenness centrality=0.000
# 여기저기: degree centrality=0.043, closeness centrality=0.311, betweenness centrality=0.027
# 다녀: degree centrality=0.055, closeness centrality=0.276, betweenness centrality=0.000
# 봐야: degree centrality=0.000, closeness centrality=0.000, betweenness centrality=0.000
# 겠어요: degree centrality=0.067, closeness centrality=0.313, betweenness centrality=0.002
# 아직도: degree centrality=0.092, closeness centrality=0.334, betweenness centrality=0.018
# 있거든요: degree centrality=0.080, closeness centrality=0.319, betweenness centrality=0.007
# ^^개의: degree centrality=0.018, closeness centrality=0.256, betweenness centrality=0.011

# %% [markdown]
# 스트 데이터를 가지고 단어 빈도수를 계산한 후, 단어 간의 연결을 만들어 NetworkX 그래프 객체를 생성합니다. 이 그래프에서 중심성 지수(degree, closeness, betweenness centrality)를 계산하고 출력합니다.
#
# 위 코드에서는 단어 간의 연결을 만들기 위해 두 단어의 길이가 1 이상인 경우에만 연결을 생성합니다. 이 연결은 두 단어에 공통으로 존재하는 문자의 수로 가중치를 부여합니다. 이렇게 생성된 그래프에서 중심성 지수를 계산하면, 각 단어의 네트워크에서의 중요도를 파악할 수 있습니다.
# 입력된 텍스트 데이터에서 추출한 단어 간의 연결과 중심성 지수가 출력됩니다.

# %%
# 그래프를 시각화합니다.
plt.figure(figsize=(20,15))
pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_size=[count * 200 for count in word_counts.values()], node_color='lightblue')
nx.draw_networkx_edges(G, pos, alpha=0.3)
nx.draw_networkx_labels(G, pos, font_size=12, font_family="AppleGothic")
plt.axis('off')
plt.show()
