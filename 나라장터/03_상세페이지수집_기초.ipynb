# %% [markdown]
# ## pandas만을 사용해 상세 페이지 정보 가져오기

# %%
import pandas as pd

# %% [markdown]
# ## 입찰공고번호로 query string 만들기

# %%
# 20200819660-01
# 20200905084-00
bidno = "20200905275"
bidseq = "00"
url = "http://www.g2b.go.kr:8081/ep/invitation/publish/bidInfoDtl.do"
url = f"{url}?bidno={bidno}&bidseq={bidseq}&releaseYn=Y&taskClCd=5"
url
# Out:
# 'http://www.g2b.go.kr:8081/ep/invitation/publish/bidInfoDtl.do?bidno=20200905275&bidseq=00&releaseYn=Y&taskClCd=5'

# %%
def get_bid_url(bidno, bidseq):
    """입찰공고번호와 차수로 입찰공고 상세페이지 url을 만듭니다."""
    url = "http://www.g2b.go.kr:8081/ep/invitation/publish/bidInfoDtl.do"
    url = f"{url}?bidno={bidno}&bidseq={bidseq}&releaseYn=Y&taskClCd=5"
    return url

# %% [markdown]
# ## table tag를 수집합니다.

# %%
table = pd.read_html(url)
len(table)
# Out:
# 9

# %% [markdown]
# ## 수집한 데이터 확인하기
# * 어떻게 전처리를 할지 살펴봅니다.

# %%
table[0]
# Out:
#             0                                1
# 0   입찰집행 부가정보                         지명경쟁자료조회
# 1  신청서/입찰서 제출  실적심사신청  적격심사신청  공동수급협정서관리  지문투찰

# %%
table[1]
# Out:
#              0                                                  1  \
# 0         공고종류                                                실공고
# 1       입찰공고번호                                   20200905275 - 00
# 2          공고명  GS칼텍스함께하는 2020년 한가위 사랑의 온정나누기 (긴급공고)  본 공고는 지문...
# 3         공고기관                                       여수시지역사회보장협의체
# 4        공고담당자                                김민이  (061-662-7750)
# 5           검사                                                NaN
# 6         입찰방식                                               전자입찰
# 7         계약방법                                             제한(총액)
# 8          재입찰          재입찰 허용  (재입찰시 기존 예비가격을 사용하여 예정가격이 산정됩니다.)
# 9         채권자명                                    여수시지역사회보장협의체위원장
# 10    발주계획통합번호                            1-3-2020-Z027365-000001
# 11    사전규격등록번호                                             903279
# 12  국내/국제 입찰사유                        국제입찰 비대상(고시금액 이하 또는 대상기관아님)
# 13        입찰자격                                             공고서 참조
# 14        관련공고                                                NaN
#
#                                                     2  \
# 0                                                게시일시
# 1                                                참조번호
# 2   GS칼텍스함께하는 2020년 한가위 사랑의 온정나누기 (긴급공고)  본 공고는 지문...
# 3                                                수요기관
# 4                                                 집행관
# 5                                                  검수
# 6                                                낙찰방법
# 7                                              국제입찰구분
# 8           재입찰 허용  (재입찰시 기존 예비가격을 사용하여 예정가격이 산정됩니다.)
# 9                                     여수시지역사회보장협의체위원장
# 10                            1-3-2020-Z027365-000001
# 11                                             903279
# 12                        국제입찰 비대상(고시금액 이하 또는 대상기관아님)
# 13                                             공고서 참조
# 14                                                NaN
#
#                                                     3
# 0                                    2020/09/06 13:38
# 1                                          4178262840
# 2   GS칼텍스함께하는 2020년 한가위 사랑의 온정나누기 (긴급공고)  본 공고는 지문...
# 3                                        여수시지역사회보장협의체
# 4                                                 김민이
# 5                                                 NaN
# 6                                              공고서 참조
# 7                                                국내입찰
# 8           재입찰 허용  (재입찰시 기존 예비가격을 사용하여 예정가격이 산정됩니다.)
# 9                                     여수시지역사회보장협의체위원장
# 10                            1-3-2020-Z027365-000001
# 11                                             903279
# 12                        국제입찰 비대상(고시금액 이하 또는 대상기관아님)
# 13                                             공고서 참조
# 14                                                NaN

# %%
table[2]
# Out:
#                   0                                                  1  \
# 0            입찰개시일시                                2020/09/07 09:00:00
# 1          개찰(입찰)일시                                2020/09/11 17:00:00
# 2      입찰참가자격등록마감일시  2020/09/10 18:00:00  조달청 입찰참가등록 가능시간은 평일 09:00...
# 3         보증서접수마감일시  보증서 접수마감일시를 입력하지 않은 경우에는, 입찰서 접수마감일 전일 18시까지 제...
# 4           실적심사신청서                                                 없음
# 5       공동수급협정서접수여부                                          없음 공동수급불허
# 6  동가입찰 낙찰자자동추첨프로그램                                          별도추첨  도움말
# 7          연구개발물품여부                                                아니오
#
#                                                    2  \
# 0                                             입찰마감일시
# 1                                               개찰장소
# 2  2020/09/10 18:00:00  조달청 입찰참가등록 가능시간은 평일 09:00...
# 3  보증서 접수마감일시를 입력하지 않은 경우에는, 입찰서 접수마감일 전일 18시까지 제...
# 4                                        실적심사신청서신청기한
# 5                                        공동수급협정서마감일시
# 6                                          별도추첨  도움말
# 7                                                아니오
#
#                                                    3
# 0                                2020/09/11 16:00:00
# 1                                  국가종합전자조달시스템(나라장터)
# 2  2020/09/10 18:00:00  조달청 입찰참가등록 가능시간은 평일 09:00...
# 3  보증서 접수마감일시를 입력하지 않은 경우에는, 입찰서 접수마감일 전일 18시까지 제...
# 4                                                NaN
# 5                                         마감: 공고서 참조
# 6                                          별도추첨  도움말
# 7                                                아니오

# %%
table[3]
# Out:
#       0                           1         2            3
# 0  예가방법  복수예가 : 4 (추첨예가) / 15 (총예가)  추첨번호공개여부          비공개
# 1  배정예산                 68,850,000원      추정가격  68,850,000원

# %%
table[4]
# Out:
#                     0                   1
# 0                지역제한                투찰제한
# 1              참가가능지역          [전라남도 여수시]
# 2            지사투찰허용여부              지사투찰불허
# 3                업종제한              공고서 참조
# 4            물품분류제한여부  물품분류로 입찰참가 제한하지 않음
# 5  공동수급체 구성원 지역제한적용여부             공고서에 의함

# %%
table[5]
# Out:
#             입찰분류           가용금액
# 0  공개된 정보가 없습니다.  공개된 정보가 없습니다.

# %%
table[6]
# Out:
#      분류  기초금액    비고  상세보기
# 0  자료없음  자료없음  자료없음  자료없음

# %% [markdown]
# ## 수집된 데이터 인덱스-값 형태로 만들기

# %%
# table[2]를 table_2라는 변수에 담아 재사용합니다.
table_2 = table[2]

# 0~3까지의 컬럼-값, 컬럼-값을 컬럼-값으로 만듭니다.
# [0, 1] 번 컬럼을 가져와서 desc 라는 변수에 담습니다.
desc_01 = table_2[[0, 1]]
# [2, 3] 번 컬럼을 가져와서 desc 라는 변수에 담습니다.
desc_02 = table_2[[2, 3]]
# 컬럼값을 변경해 줍니다.
desc_01.columns = ["컬럼명", "내용"]
desc_02.columns = ["컬럼명", "내용"]

# %% [markdown]
# ## 여러 데이터 프레임 합치기
# * 컬럼명이 같다면 concat을 통해 하나의 데이터 프레임으로 합칠 수 있습니다.
# <img src="https://pandas.pydata.org/pandas-docs/stable/_images/merging_concat_basic.png">

# %%
# 위에서 전처리한 데이터를 합쳐줍니다.
desc = pd.concat([desc_01, desc_02])
desc.shape
# Out:
# (16, 2)

# %%
# colspan 으로 합쳐진 데이터에는 같은 내용이 들어가 있습니다. 이 데이터는 제외합니다.
desc = desc[desc["컬럼명"] != desc["내용"]]
# 데이터가 모두 결측치라면 제거합니다.
desc = desc.dropna(how="all")
desc = desc.set_index("컬럼명")
desc
# Out:
#                                                                  내용
# 컬럼명
# 입찰개시일시                                          2020/09/07 09:00:00
# 개찰(입찰)일시                                        2020/09/11 17:00:00
# 입찰참가자격등록마감일시      2020/09/10 18:00:00  조달청 입찰참가등록 가능시간은 평일 09:00...
# 보증서접수마감일시         보증서 접수마감일시를 입력하지 않은 경우에는, 입찰서 접수마감일 전일 18시까지 제...
# 실적심사신청서                                                          없음
# 공동수급협정서접수여부                                               없음 공동수급불허
# 동가입찰 낙찰자자동추첨프로그램                                          별도추첨  도움말
# 연구개발물품여부                                                        아니오
# 입찰마감일시                                          2020/09/11 16:00:00
# 개찰장소                                              국가종합전자조달시스템(나라장터)
# 실적심사신청서신청기한                                                     NaN
# 공동수급협정서마감일시                                              마감: 공고서 참조

# %% [markdown]
# ## 함수로 만들기

# %%
def parse_table(table_data):
    """
    컬럼이 4개인 table 태그에서 컬럼-값 형태로 전처리를 해서 반환합니다.
    컬럼이 3개보다 작으면 입력값을 전처리 후 반환합니다.
    """
    
    col_count = table_data.shape[1]
    if  col_count % 2 == 1:
        return
    
    if col_count < 3 :
        table_data.columns = ["컬럼명", "내용"]
        table_data = table_data[table_data["컬럼명"] != table_data["내용"]]
        table_data = table_data.set_index("컬럼명")
        return table_data
        
    desc_01 = table_data.iloc[:, [0, 1]]
    desc_02 = table_data.iloc[:, [2, 3]]
    # concat을 위해 컬럼명을 desc_01과 같도록 만듭니다.
    desc_01.columns = ["컬럼명", "내용"]
    desc_02.columns = ["컬럼명", "내용"]
    # 전처리한 데이터를 붙여줍니다.
    desc = pd.concat([desc_01, desc_02])
    # colspan 으로 합쳐진 데이터에는 같은 내용이 들어가 있습니다. 이 데이터는 제외합니다.
    # 컬럼명과 내용이 다른 데이터만 사용합니다.
    desc = desc[desc["컬럼명"] != desc["내용"]]
    # 데이터가 모두 결측치라면 제거합니다.
    desc = desc.dropna(how="all")
    # 컬럼명을 인덱스로 설정합니다.
    desc = desc.set_index("컬럼명")
    # 처리가 끝난 desc 값을 반환합니다.
    return desc

# %%
parse_table(table[1])
# Out:
#                                                            내용
# 컬럼명
# 공고종류                                                      실공고
# 입찰공고번호                                       20200905275 - 00
# 공고명         GS칼텍스함께하는 2020년 한가위 사랑의 온정나누기 (긴급공고)  본 공고는 지문...
# 공고기관                                             여수시지역사회보장협의체
# 공고담당자                                     김민이  (061-662-7750)
# 검사                                                        NaN
# 입찰방식                                                     전자입찰
# 계약방법                                                   제한(총액)
# 재입찰                 재입찰 허용  (재입찰시 기존 예비가격을 사용하여 예정가격이 산정됩니다.)
# 채권자명                                          여수시지역사회보장협의체위원장
# 발주계획통합번호                              1-3-2020-Z027365-000001
# 사전규격등록번호                                               903279
# 국내/국제 입찰사유                        국제입찰 비대상(고시금액 이하 또는 대상기관아님)
# 입찰자격                                                   공고서 참조
# 관련공고                                                      NaN
# 게시일시                                         2020/09/06 13:38
# 참조번호                                               4178262840
# 수요기관                                             여수시지역사회보장협의체
# 집행관                                                       김민이
# 검수                                                        NaN
# 낙찰방법                                                   공고서 참조
# 국제입찰구분                                                   국내입찰

# %%
parse_table(table[2])
# Out:
#                                                                  내용
# 컬럼명
# 입찰개시일시                                          2020/09/07 09:00:00
# 개찰(입찰)일시                                        2020/09/11 17:00:00
# 입찰참가자격등록마감일시      2020/09/10 18:00:00  조달청 입찰참가등록 가능시간은 평일 09:00...
# 보증서접수마감일시         보증서 접수마감일시를 입력하지 않은 경우에는, 입찰서 접수마감일 전일 18시까지 제...
# 실적심사신청서                                                          없음
# 공동수급협정서접수여부                                               없음 공동수급불허
# 동가입찰 낙찰자자동추첨프로그램                                          별도추첨  도움말
# 연구개발물품여부                                                        아니오
# 입찰마감일시                                          2020/09/11 16:00:00
# 개찰장소                                              국가종합전자조달시스템(나라장터)
# 실적심사신청서신청기한                                                     NaN
# 공동수급협정서마감일시                                              마감: 공고서 참조

# %%
parse_table(table[3])
# Out:
#                                   내용
# 컬럼명
# 예가방법      복수예가 : 4 (추첨예가) / 15 (총예가)
# 배정예산                     68,850,000원
# 추첨번호공개여부                         비공개
# 추정가격                     68,850,000원

# %%
parse_table(table[4])
# Out:
#                                     내용
# 컬럼명
# 지역제한                              투찰제한
# 참가가능지역                      [전라남도 여수시]
# 지사투찰허용여부                        지사투찰불허
# 업종제한                            공고서 참조
# 물품분류제한여부            물품분류로 입찰참가 제한하지 않음
# 공동수급체 구성원 지역제한적용여부             공고서에 의함

# %%
parse_table(table[5])
# Out:
# Empty DataFrame
# Columns: [내용]
# Index: []

# %% [markdown]
# ## 여러 테이블을 반복문으로 전처리 하고 이어 붙이기

# %%
# 전처리한 테이블들을 리스트에 담아주고 concat안에 담아주면 하나의 데이터프레임으로 합쳐줍니다.
desc_list = []
for table_no in range(1, 6):
    table_result = parse_table(table[table_no])
    desc_list.append(table_result)

# %%
pd.concat(desc_list)
# Out:
#                                                                    내용
# 컬럼명
# 공고종류                                                              실공고
# 입찰공고번호                                               20200905275 - 00
# 공고명                 GS칼텍스함께하는 2020년 한가위 사랑의 온정나누기 (긴급공고)  본 공고는 지문...
# 공고기관                                                     여수시지역사회보장협의체
# 공고담당자                                             김민이  (061-662-7750)
# 검사                                                                NaN
# 입찰방식                                                             전자입찰
# 계약방법                                                           제한(총액)
# 재입찰                         재입찰 허용  (재입찰시 기존 예비가격을 사용하여 예정가격이 산정됩니다.)
# 채권자명                                                  여수시지역사회보장협의체위원장
# 발주계획통합번호                                      1-3-2020-Z027365-000001
# 사전규격등록번호                                                       903279
# 국내/국제 입찰사유                                국제입찰 비대상(고시금액 이하 또는 대상기관아님)
# 입찰자격                                                           공고서 참조
# 관련공고                                                              NaN
# 게시일시                                                 2020/09/06 13:38
# 참조번호                                                       4178262840
# 수요기관                                                     여수시지역사회보장협의체
# 집행관                                                               김민이
# 검수                                                                NaN
# 낙찰방법                                                           공고서 참조
# 국제입찰구분                                                           국내입찰
# 입찰개시일시                                            2020/09/07 09:00:00
# 개찰(입찰)일시                                          2020/09/11 17:00:00
# 입찰참가자격등록마감일시        2020/09/10 18:00:00  조달청 입찰참가등록 가능시간은 평일 09:00...
# 보증서접수마감일시           보증서 접수마감일시를 입력하지 않은 경우에는, 입찰서 접수마감일 전일 18시까지 제...
# 실적심사신청서                                                            없음
# 공동수급협정서접수여부                                                 없음 공동수급불허
# 동가입찰 낙찰자자동추첨프로그램                                            별도추첨  도움말
# 연구개발물품여부                                                          아니오
# 입찰마감일시                                            2020/09/11 16:00:00
# 개찰장소                                                국가종합전자조달시스템(나라장터)
# 실적심사신청서신청기한                                                       NaN
# 공동수급협정서마감일시                                                마감: 공고서 참조
# 예가방법                                       복수예가 : 4 (추첨예가) / 15 (총예가)
# 배정예산                                                      68,850,000원
# 추첨번호공개여부                                                          비공개
# 추정가격                                                      68,850,000원
# 지역제한                                                             투찰제한
# 참가가능지역                                                     [전라남도 여수시]
# 지사투찰허용여부                                                       지사투찰불허
# 업종제한                                                           공고서 참조
# 물품분류제한여부                                           물품분류로 입찰참가 제한하지 않음
# 공동수급체 구성원 지역제한적용여부                                            공고서에 의함

# %% [markdown]
# ## 전체 과정을 하나의 함수로 만들기

# %%
def get_bid_info(bidno, bidseq):
    """상세페이지 정보를 가져옵니다. 내부에서 get_bid_url, parse_table 을 호출합니다."""
    url = get_bid_url(bidno, bidseq)
    
    try:
        table = pd.read_html(url)
        desc_list = []
        for table_no in range(2, 6):
            table_result = parse_table(table[table_no])
            desc_list.append(table_result)

        return pd.concat(desc_list)
    except:
        return False

# %% [markdown]
# ## 함수 동작 확인

# %%
# 잘못된 정보 전달

bidno = "202008196643"
bidseq = "01"

get_bid_info(bidno, bidseq)
# Out:
# False

# %%
bidno = "20200905275"
bidseq = "00"

get_bid_info(bidno, bidseq)
# Out:
#                                                                    내용
# 컬럼명
# 입찰개시일시                                            2020/09/07 09:00:00
# 개찰(입찰)일시                                          2020/09/11 17:00:00
# 입찰참가자격등록마감일시        2020/09/10 18:00:00  조달청 입찰참가등록 가능시간은 평일 09:00...
# 보증서접수마감일시           보증서 접수마감일시를 입력하지 않은 경우에는, 입찰서 접수마감일 전일 18시까지 제...
# 실적심사신청서                                                            없음
# 공동수급협정서접수여부                                                 없음 공동수급불허
# 동가입찰 낙찰자자동추첨프로그램                                            별도추첨  도움말
# 연구개발물품여부                                                          아니오
# 입찰마감일시                                            2020/09/11 16:00:00
# 개찰장소                                                국가종합전자조달시스템(나라장터)
# 실적심사신청서신청기한                                                       NaN
# 공동수급협정서마감일시                                                마감: 공고서 참조
# 예가방법                                       복수예가 : 4 (추첨예가) / 15 (총예가)
# 배정예산                                                      68,850,000원
# 추첨번호공개여부                                                          비공개
# 추정가격                                                      68,850,000원
# 지역제한                                                             투찰제한
# 참가가능지역                                                     [전라남도 여수시]
# 지사투찰허용여부                                                       지사투찰불허
# 업종제한                                                           공고서 참조
# 물품분류제한여부                                           물품분류로 입찰참가 제한하지 않음
# 공동수급체 구성원 지역제한적용여부                                            공고서에 의함

# %%
# 정상 정보 전달
bidno = "20200819660"
bidseq = "01"

get_bid_info(bidno, bidseq)
# Out:
#                                                                    내용
# 컬럼명
# 공고종류                                                              실공고
# 입찰공고번호                                               20200819660 - 01
# 공고명                 잎새지하차도 연장 타당성 재검증 용역 (긴급공고)  (취소공고)  본 공고는 지문인...
# 공고기관                                                          경기도 화성시
# 공고담당자                                            남유진  (031-5189-2491)
# 입찰방식                                                             전자입찰
# 계약방법                                                             제한경쟁
# 재입찰                         재입찰 허용  (재입찰시 기존 예비가격을 사용하여 예정가격이 산정됩니다.)
# 용역구분                                                             기술용역
# 발주계획번호                                        5-1-2020-5530000-000210
# 사전규격등록번호                                                       901631
# 국내/국제 입찰사유                                국제입찰 비대상(고시금액 이하 또는 대상기관아님)
# WTO품목번호                                                           NaN
# 입찰자격                                                           공고서 참조
# 관련공고                                                 20200819660 - 00
# 게시일시                                                 2020/09/06 16:09
# 참조번호                                                        2020-2846
# 수요기관                                                          경기도 화성시
# 집행관                                                               남유진
# 낙찰방법                                                           공고서 참조
# 국제입찰구분                                                           국내입찰
# 채권자명                                                          화성시 재무관
# 입찰개시일시                                            2020/08/24 09:00:00
# 개찰(입찰)일시                                          2020/08/27 11:00:00
# 입찰참가자격등록마감일시        2020/08/26 18:00:00  조달청 입찰참가등록 가능시간은 평일 09:00...
# 보증서접수마감일시           보증서 접수마감일시를 입력하지 않은 경우에는, 입찰서 접수마감일 전일 18시까지 제...
# 공동수급협정서접수여부                                     방식: 전자문서  분담이행 방식만 허용
# PQ심사신청서                                                           NaN
# TP심사신청서                                                            없음
# 실적심사신청서                                                        방식: 없음
# 과업설명장소                                                            NaN
# 동가입찰 낙찰자자동추첨프로그램                                              사용  도움말
# 입찰마감일시                                            2020/08/27 10:00:00
# 개찰장소                                                국가종합전자조달시스템(나라장터)
# 공동수급협정서마감일시                                   마감: 2020/08/26 18:00:00
# PQ심사신청서신청기한                                                       NaN
# TP심사신청서신청기한                                                       NaN
# 실적심사신청서신청기한                                                       NaN
# 과업설명일시                                                            NaN
# 예가방법                                       복수예가 : 4 (추첨예가) / 15 (총예가)
# 배정예산                                                     246,489,000원
# 추첨번호공개여부                                                          비공개
# 추정가격                                                     224,080,909원
# 지역제한                                                           공고서 참조
# 업종제한                                                           공고서 참조
# 과업설명 제한여부                                                      참가제한안함
# 공동수급체 구성원 지역제한적용여부                                            공고서에 의함

# %%
# 20200905275-00

bidno = "20200905275"
bidseq = "00"

get_bid_info(bidno, bidseq)
# Out:
#                                                                    내용
# 컬럼명
# 입찰개시일시                                            2020/09/07 09:00:00
# 개찰(입찰)일시                                          2020/09/11 17:00:00
# 입찰참가자격등록마감일시        2020/09/10 18:00:00  조달청 입찰참가등록 가능시간은 평일 09:00...
# 보증서접수마감일시           보증서 접수마감일시를 입력하지 않은 경우에는, 입찰서 접수마감일 전일 18시까지 제...
# 실적심사신청서                                                            없음
# 공동수급협정서접수여부                                                 없음 공동수급불허
# 동가입찰 낙찰자자동추첨프로그램                                            별도추첨  도움말
# 연구개발물품여부                                                          아니오
# 입찰마감일시                                            2020/09/11 16:00:00
# 개찰장소                                                국가종합전자조달시스템(나라장터)
# 실적심사신청서신청기한                                                       NaN
# 공동수급협정서마감일시                                                마감: 공고서 참조
# 예가방법                                       복수예가 : 4 (추첨예가) / 15 (총예가)
# 배정예산                                                      68,850,000원
# 추첨번호공개여부                                                          비공개
# 추정가격                                                      68,850,000원
# 지역제한                                                             투찰제한
# 참가가능지역                                                     [전라남도 여수시]
# 지사투찰허용여부                                                       지사투찰불허
# 업종제한                                                           공고서 참조
# 물품분류제한여부                                           물품분류로 입찰참가 제한하지 않음
# 공동수급체 구성원 지역제한적용여부                                            공고서에 의함
