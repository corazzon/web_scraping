# %% [markdown]
# * [HTTP - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/HTTP)
# * [HTTP 상태 코드 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/HTTP_%EC%83%81%ED%83%9C_%EC%BD%94%EB%93%9C)

# %%
import pandas as pd

# %%
url = "https://ko.wikipedia.org/wiki/HTTP"

# %%
tables = pd.read_html(url)
len(tables)
# Out:
# 14

# %%
tables[3]
# Out:
#   HTTP 메소드       RFC 요청에 Body가 있음 응답에 Body가 있음   안전 멱등(Idempotent) 캐시 가능
# 0      GET  RFC 7231          아니요            예    예              예     예
# 1     HEAD  RFC 7231          아니요          아니요    예              예     예
# 2     POST  RFC 7231            예            예  아니요            아니요     예
# 3      PUT  RFC 7231            예            예  아니요              예   아니요
# 4   DELETE  RFC 7231          아니요            예  아니요              예   아니요
# 5  CONNECT  RFC 7231            예            예  아니요            아니요   아니요
# 6  OPTIONS  RFC 7231        선택 사항            예    예              예   아니요
# 7    TRACE  RFC 7231          아니요            예    예              예   아니요
# 8    PATCH  RFC 5789            예            예  아니요            아니요     예

# %%
tables[4]
# Out:
#         코드                            메시지  \
# 0      1XX              Informational(정보)
# 1      100                       Continue
# 2      101            Switching Protocols
# 3      2XX                    Success(성공)
# 4      200                             OK
# 5      202                       Accepted
# 6      203  Non-authoritavive Information
# 7      204                    Non Content
# 8      205                  Reset Content
# 9      206                Partial Content
# 10     3XX             Redirection(방향 바꿈)
# 11     300               Multiple Choices
# 12     301              Moved Permanently
# 13     302              Moved Permanently
# 14     303                      See Other
# 15     304                   Not modified
# 16     305                      Use Proxy
# 17     307             Temporary Redirect
# 18     4XX         Client Error(클라이언트 오류)
# 19     400                    Bad Request
# 20   401.1                   Unauthorized
# 21   401.2                   Unauthorized
# 22   401.3                   Unauthorized
# 23   401.4                   Unauthorized
# 24   401.5                   Unauthorized
# 25     402               Payment Required
# 26   403.1                      Forbidden
# 27   403.2                      Forbidden
# 28   403.4                      Forbidden
# 29   403.5                      Forbidden
# 30   403.6                      Forbidden
# 31   403.7                      Forbidden
# 32   403.8                      Forbidden
# 33   403.9                      Forbidden
# 34  403.10                      Forbidden
# 35  403.11                      Forbidden
# 36  403.12                      Forbidden
# 37     404                      Not Found
# 38     405             Method not allowed
# 39     406                 Not Acceptable
# 40     407  Proxy Authentication Required
# 41     408                Request timeout
# 42     409                       Conflict
# 43     410                           Gone
# 44     411                Length Required
# 45     412            Precondition Failed
# 46     413       Request entity too large
# 47     414           Request-URI too long
# 48     415         Unsupported media type
# 49     5XX            Server Error(서버 오류)
# 50     500          Internal Server Error
# 51     501                Not Implemented
# 52     502                    Bad gateway
# 53     503            Service Unavailable
# 54     504                Gateway timeout
# 55     505     HTTP Version Not Supported
#
#                                                    설명
# 0                                              정보 교환.
# 1   클라이언트로부터 일부 요청을 받았으니 나머지 요청 정보를 계속 보내주길 바람. (H...
# 2   서버는 클라이언트의 요청대로 Upgrade 헤더를 따라 다른 프로토콜로 바꿀 것임....
# 3                데이터 전송이 성공적으로 이루어졌거나, 이해되었거나, 수락되었음.
# 4                                        오류 없이 전송 성공.
# 5                                 서버가 클라이언트의 요청을 수락함.
# 6                               서버가 클라이언트 요구중 일부만 전송.
# 7                       클라이언트의 요구를 처리했으나 전송할 데이터가 없음.
# 8   새 문서 없음. 하지만 브라우저는 문서 창을 리셋해야 함. (브라우저가 CGI 폼 ...
# 9   클라이언트가 Range 헤더와 함께 요청의 일부분을 보냈고 서버는 이를 수행했음. ...
# 10                                      자료의 위치가 바뀌었음.
# 11                                   최근에 옮겨진 데이터를 요청.
# 12                            요구한 데이터를 변경된 URL에서 찾았음.
# 13  요구한 데이터가 변경된 URL에 있음을 명시. 301과 비슷하지만 새 URL은 임시...
# 14                      요구한 데이터를 변경하지 않았기 때문에 문제가 있음.
# 15  클라이언트의 캐시에 이 문서가 저장되었고 선택적인 요청에 의해 수행됨 (보통 지정된...
# 16  요청된 문서는 Location 헤더에 나열된 프록시를 통해 추출되어야 함. (HTT...
# 17                                     자료가 임시적으로 옮겨짐.
# 18             클라이언트 측의 오류. 주소를 잘못 입력하였거나 요청이 잘못 되었음.
# 19          요청 실패. 문법상 오류가 있어서 서버가 요청사항을 이해하지 못함,[10]
# 20  권한 없음 (접속실패). 서버에 로그온 하려는 요청사항이 서버에 들어있는 권한과 비...
# 21  권한 없음 (서버설정으로 인한 접속 실패). 서버에 로그온 하려는 요청사항이 서버에...
# 22  권한 없음 (자원에 대한 ACL에 기인한 권한 없음). 클라이언트가 특정 자료에 접...
# 23  권한 없음 (필터에 의한 권한 부여 실패). 서버에 접속하는 사용자들을 확인하기 위...
# 24  권한 없음 (ISA PI/CGI 애플리케이션에 의한 권한부여 실패). 이용하려는 서...
# 25                                               예약됨.
# 26  금지 (수행접근 금지). 수행시키지 못하도록 되어있는 디렉터리 내의 실행 파일을 수...
# 27       금지 (읽기 접근 금지). 접근한 디렉터리에 가용한 기본 페이지가 없음.[16]
# 28      금지 (SSL 필요함). 접근하려는 페이지가 SSL로 보안유지 되고 있음.[17]
# 29  금지 (SSL 128필요함). 페이지가 128비트의 SSL로 보안유지 되고 있음.[18]
# 30            금지 (IP 주소 거부됨). 사용자가 허용되지 않은 IP로부터 접근함.
# 31  금지 (클라이언트 확인 필요). 클라이언트가 자료에 접근할 수 있는지 확인 요함.[19]
# 32  금지 (사이트 접근 거부됨). 서버가 요청사항을 수행하고 있지 않거나, 해당 사이트...
# 33  접근금지 (연결된 사용자수 과다). 서버가 BUSY 상태에 있어서 요청을 수행할 수...
# 34                               접근금지 (설정이 확실 하지 않음).
# 35                     접근금지 (패스워드 변경됨). 잘못된 암호를 입력했음.
# 36  접근금지(Mapper 접근 금지됨). 클라이언트 인증용 맵이 해당 웹 사이트에 접근...
# 37            문서를 찾을 수 없음. 서버가 요 청한 파일이나 스크립트를 찾지 못함.
# 38  메서드 허용 안됨. 요청 내용에 명시된 메서드를 수행하기 위해 해당 자원의 이용이 ...
# 39                                     받아들일 수 없음.[21]
# 40                               프록시 서버의 인증이 필요함.[22]
# 41                                         요청 시간이 지남.
# 42  요청을 처리하는 데 문제가 있음. 보통 PUT 요청과 관계가 있다. 보통 다른 버전...
# 43                                    영구적으로 사용할 수 없음.
# 44  클라이언트가 헤더에 Content-Length를 포함하지 않으면 서버가 처리할 수 ...
# 45      선결조건 실패. 헤더에 하나 이상의 선결조건을 서버에서 충족시킬 수 없음.[23]
# 46  요청된 문서가 현재 서버가 다룰 수 있는 크기보다 큼.[24] (HTTP 1.1에서...
# 47                                 요청한 URI가 너무 김.[25]
# 48                요청이 알려지지 않은 형태임. (HTTP 1.1에서 새로 등장)
# 49                        서버 측의 오류로 올바른 요청을 처리할 수 없음.
# 50                                      서버 내부 오류.[26]
# 51                          필요한 기능이 서버에 설치되지 않았음.[27]
# 52                                   게이트웨이 상태 나쁨.[28]
# 53         외부 서비스가 죽었거나 현재 멈춘 상태 또는 이용할 수 없는 서비스.[29]
# 54  프록시나 게이트웨이의 역할을 하는 서버에서 볼 수 있음. 초기 서버가 원격 서버로부...
# 55                               해당 HTTP 버전을 지원하지 않음.
