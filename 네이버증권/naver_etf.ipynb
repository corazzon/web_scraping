# %% [markdown]
# ## 네트워크의 JS탭을 확인

# %%
import pandas as pd

# %%
url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc"

# %%
# requests 라이브러리를 통해 url을 받아옵니다.
import requests
response = requests.get(url)

# %%
# requests 의 응답을 json 타입으로 받습니다.
etf_json = response.json()

# %%
# result > etfItemList 의 하위 구조로 목록을 찾아 들어갑니다.
etfItemList = etf_json["result"]["etfItemList"]

# %%
df = pd.DataFrame(etfItemList)
df.shape
# Out:
# (450, 12)

# %%
df.head()
# Out:
#   itemcode  etfTabCode          itemname  nowVal risefall  changeVal  \
# 0   069500           1         KODEX 200   31420        5       -205
# 1   102110           1         TIGER 200   31420        5       -180
# 2   252670           3  KODEX 200선물인버스2X    4125        2         65
# 3   122630           3        KODEX 레버리지   15065        5       -230
# 4   153130           6        KODEX 단기채권  102465        3          0
#
#    changeRate       nav  threeMonthEarnRate     quant  amonut  marketSum
# 0       -0.65   31502.0              8.5762   3642902  114615      47916
# 1       -0.57   31502.0              8.5649    889443   27984      26471
# 2        1.60    4131.0            -19.5243  92658294  380950      24181
# 3       -1.50   15142.0             15.7834  25797026  389939      21121
# 4        0.00  102468.0              0.0976     11274    1155      17629

# %%
df.tail()
# Out:
#     itemcode  etfTabCode         itemname  nowVal risefall  changeVal  \
# 445   295820           1  ARIRANG 200동일가중    8560        5        -60
# 446   287300           2     KBSTAR 200건설    8025        5       -185
# 447   284980           2     KBSTAR 200금융    6590        5        -45
# 448   287310           2  KBSTAR 200경기소비재    8485        5        -15
# 449   266140           2       TIGER 지속배당   11990        5        -95
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 445       -0.70   8573.0              7.8173     23       0         21
# 446       -2.25   8020.0             -0.4245     31       0         21
# 447       -0.68   6606.0             -2.4982    142       0         20
# 448       -0.18   8481.0             12.1372     12       0         15
# 449       -0.79  12042.0              4.8590      3       0         11

# %%
df.sort_values(["quant"], ascending=False).head(10)
# Out:
#    itemcode  etfTabCode           itemname  nowVal risefall  changeVal  \
# 2    252670           3   KODEX 200선물인버스2X    4125        2         65
# 3    122630           3         KODEX 레버리지   15065        5       -230
# 22   251340           3  KODEX 코스닥150선물인버스    5135        2         70
# 8    114800           3          KODEX 인버스    5440        2         50
# 11   233740           1  KODEX 코스닥150 레버리지   13605        5       -345
# 0    069500           1          KODEX 200   31420        5       -205
# 29   229200           1      KODEX 코스닥 150   13610        5       -170
# 59   252710           3   TIGER 200선물인버스2X    4260        2         60
# 21   261220           5   KODEX WTI원유선물(H)    5870        5       -130
# 1    102110           1          TIGER 200   31420        5       -180
#
#     changeRate      nav  threeMonthEarnRate     quant  amonut  marketSum
# 2         1.60   4131.0            -19.5243  92658294  380950      24181
# ...

# %%
df_inverse = df[df.itemname.str.contains("인버스")]

# %%
df_not_inverse = df[~df.itemname.str.contains("인버스")]
df_not_inverse
# Out:
#     itemcode  etfTabCode              itemname  nowVal risefall  changeVal  \
# 0     069500           1             KODEX 200   31420        5       -205
# 1     102110           1             TIGER 200   31420        5       -180
# 3     122630           3            KODEX 레버리지   15065        5       -230
# 4     153130           6            KODEX 단기채권  102465        3          0
# 5     273130           6  KODEX 종합채권(AA-이상)액티브  110405        5        -65
# ..       ...         ...                   ...     ...      ...        ...
# 445   295820           1       ARIRANG 200동일가중    8560        5        -60
# 446   287300           2          KBSTAR 200건설    8025        5       -185
# 447   284980           2          KBSTAR 200금융    6590        5        -45
# 448   287310           2       KBSTAR 200경기소비재    8485        5        -15
# 449   266140           2            TIGER 지속배당   11990        5        -95
#
# ...

# %%
df_inverse.sort_values(by=["quant"], ascending=False).head(10)
# Out:
#     itemcode  etfTabCode            itemname  nowVal risefall  changeVal  \
# 2     252670           3    KODEX 200선물인버스2X    4125        2         65
# 22    251340           3   KODEX 코스닥150선물인버스    5135        2         70
# 8     114800           3           KODEX 인버스    5440        2         50
# 59    252710           3    TIGER 200선물인버스2X    4260        2         60
# 125   250780           3   TIGER 코스닥150선물인버스    5230        2         75
# 111   252420           3   KBSTAR 200선물인버스2X    4125        2         75
# 169   253160           3  ARIRANG 200선물인버스2X    8220        2        125
# 77    123310           3           TIGER 인버스    5970        2         40
# 167   306520           3     HANARO 200선물인버스   12445        2         75
# 306   253230           3    KOSEF 200선물인버스2X    4075        2         15
#
#      changeRate      nav  threeMonthEarnRate     quant  amonut  marketSum
# 2          1.60   4131.0            -19.5243  92658294  380950      24181
# ...

# %%
df_not_inverse.sort_values(by=["quant"], ascending=False).head(10)
# Out:
#    itemcode  etfTabCode                  itemname  nowVal risefall  changeVal  \
# 3    122630           3                KODEX 레버리지   15065        5       -230
# 11   233740           1         KODEX 코스닥150 레버리지   13605        5       -345
# 0    069500           1                 KODEX 200   31420        5       -205
# 29   229200           1             KODEX 코스닥 150   13610        5       -170
# 21   261220           5          KODEX WTI원유선물(H)    5870        5       -130
# 1    102110           1                 TIGER 200   31420        5       -180
# 61   267770           3           TIGER 200선물레버리지   11345        5       -185
# 98   219390           4  KBSTAR 미국S&P원유생산기업(합성 H)    2035        5       -110
# 55   130680           5     TIGER 원유선물Enhanced(H)    1925        5        -20
# 17   278540           1       KODEX MSCI Korea TR   10000        5        -80
#
#     changeRate      nav  threeMonthEarnRate     quant  amonut  marketSum
# ...

# %%
df["etfTabCode"].value_counts()
# Out:
# 2    165
# 4     85
# 1     62
# 6     56
# 3     35
# 7     33
# 5     14
# Name: etfTabCode, dtype: int64

# %%
df[df["etfTabCode"] == 1]
# Out:
#     itemcode  etfTabCode           itemname  nowVal risefall  changeVal  \
# 0     069500           1          KODEX 200   31420        5       -205
# 1     102110           1          TIGER 200   31420        5       -180
# 9     278530           1        KODEX 200TR   10060        5        -60
# 10    148020           1         KBSTAR 200   31450        5       -235
# 11    233740           1  KODEX 코스닥150 레버리지   13605        5       -345
# ..       ...         ...                ...     ...      ...        ...
# 388   252000           1      TIGER 200동일가중    9505        2          5
# 390   291610           1     KOSEF 코스닥150선물    8760        5       -120
# 403   226980           1      KODEX 200 중소형    9790        5        -15
# 406   301400           1     ARIRANG 코스닥150   13570        5       -130
# 445   295820           1    ARIRANG 200동일가중    8560        5        -60
#
#      changeRate      nav  threeMonthEarnRate    quant  amonut  marketSum
# ...

# %%
df[df["etfTabCode"] == 2]
# Out:
#     itemcode  etfTabCode          itemname  nowVal risefall  changeVal  \
# 6     102780           2        KODEX 삼성그룹    7700        2         25
# 18    292150           2       TIGER TOP10   10775        5        -70
# 24    305720           2      KODEX 2차전지산업   12420        5       -230
# 30    305540           2      TIGER 2차전지테마   12020        5       -225
# 31    315930           2  KODEX Top5PlusTR   13575        5        -75
# ..       ...         ...               ...     ...      ...        ...
# 443   285020           2    KBSTAR 200철강소재    5400        5        -50
# 446   287300           2      KBSTAR 200건설    8025        5       -185
# 447   284980           2      KBSTAR 200금융    6590        5        -45
# 448   287310           2   KBSTAR 200경기소비재    8485        5        -15
# 449   266140           2        TIGER 지속배당   11990        5        -95
#
#      changeRate      nav  threeMonthEarnRate   quant  amonut  marketSum
# ...

# %%
df[df["etfTabCode"] == 3]
# Out:
#     itemcode  etfTabCode             itemname  nowVal risefall  changeVal  \
# 2     252670           3     KODEX 200선물인버스2X    4125        2         65
# 3     122630           3           KODEX 레버리지   15065        5       -230
# 8     114800           3            KODEX 인버스    5440        2         50
# 22    251340           3    KODEX 코스닥150선물인버스    5135        2         70
# 59    252710           3     TIGER 200선물인버스2X    4260        2         60
# 61    267770           3      TIGER 200선물레버리지   11345        5       -185
# 77    123310           3            TIGER 인버스    5970        2         40
# 84    282000           3    KBSTAR 국고채3년선물인버스   99405        2         35
# 104   252400           3     KBSTAR 200선물레버리지   13715        5       -225
# 111   252420           3    KBSTAR 200선물인버스2X    4125        2         75
# 125   250780           3    TIGER 코스닥150선물인버스    5230        2         75
# 138   253250           3      KOSEF 200선물레버리지   13470        5       -300
# ...

# %%
df[df["etfTabCode"] == 4].sort_values(by="quant", ascending=False).head(10)
# Out:
#     itemcode  etfTabCode                  itemname  nowVal risefall  \
# 98    219390           4  KBSTAR 미국S&P원유생산기업(합성 H)    2035        5
# 45    314250           4        KODEX 미국FANG플러스(H)   20630        5
# 36    192090           4           TIGER 차이나CSI300   10725        2
# 39    204480           4   TIGER 차이나CSI300레버리지(합성)   25830        5
# 81    256750           4       KODEX 심천ChiNext(합성)   10965        5
# 25    133690           4            TIGER 미국나스닥100   59875        5
# 163   276650           4    KBSTAR 글로벌4차산업IT(합성 H)   17175        5
# 164   360750           4            TIGER 미국S&P500   10060        5
# 51    275980           4   TIGER 글로벌4차산업혁신기술(합성 H)   14325        5
# 133   360200           4           KINDEX 미국S&P500   10170        5
#
#      changeVal  changeRate  nav  threeMonthEarnRate   quant  amonut  marketSum
# 98        -110       -5.13  NaN            -28.2609  625610    1281        504
# ...

# %%
df[df["etfTabCode"] == 5]
# Out:
#     itemcode  etfTabCode                itemname  nowVal risefall  changeVal  \
# 21    261220           5        KODEX WTI원유선물(H)    5870        5       -130
# 40    132030           5           KODEX 골드선물(H)   13440        5        -20
# 52    144600           5            KODEX 은선물(H)    5640        5        -85
# 55    130680           5   TIGER 원유선물Enhanced(H)    1925        5        -20
# 117   137610           5  TIGER 농산물선물Enhanced(H)    4285        2         20
# 243   271060           5        KODEX 3대농산물선물(H)    7515        2         75
# 281   160580           5              TIGER 구리실물    7435        5        -85
# 299   139320           5           TIGER 금은선물(H)   10570        5        -25
# 304   334690           5         KBSTAR 팔라듐선물(H)   13655        5        -45
# 312   271050           5     KODEX WTI원유선물인버스(H)   17280        2        320
# 324   138920           5            KODEX 콩선물(H)    8190        5         -5
# ...

# %%
df[df["etfTabCode"] == 6]
# Out:
#     itemcode  etfTabCode                   itemname  nowVal risefall  \
# 4     153130           6                 KODEX 단기채권  102465        3
# 5     273130           6       KODEX 종합채권(AA-이상)액티브  110405        5
# 7     157450           6                TIGER 단기통안채  100655        5
# 12    214980           6             KODEX 단기채권PLUS  102685        5
# 16    272580           6              TIGER 단기채권액티브   50460        3
# 28    190620           6               KINDEX 단기통안채  100795        3
# 32    306540           6               HANARO 단기통안채  102725        3
# 41    148070           6               KOSEF 국고채10년  126160        5
# 50    196230           6               KBSTAR 단기통안채  103995        3
# 62    273140           6         KODEX 단기변동금리부채권액티브  102190        3
# 72    302190           6                TIGER 중장기국채   53750        5
# 75    272560           6            KBSTAR 단기국공채액티브  101400        3
# 79    114260           6                KODEX 국고채3년   58025        5
# ...

# %%
\
