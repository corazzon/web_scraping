# %%
# !pip install --upgrade mplfinance

# %%
import pandas as pd

# %%
df = pd.read_csv("SK바이오팜_326030_2020.10.19.csv", index_col="날짜", parse_dates=True)
df = df.sort_index()
df.head()
# Out:
#               종목코드     종목명        종가      전일비        시가        고가        저가  \
# 날짜
# 2020-07-02  326030  SK바이오팜  127000.0  29000.0   98000.0  127000.0   98000.0
# 2020-07-03  326030  SK바이오팜  165000.0  38000.0  165000.0  165000.0  165000.0
# 2020-07-06  326030  SK바이오팜  214500.0  49500.0  214500.0  214500.0  193500.0
# 2020-07-07  326030  SK바이오팜  216500.0   2000.0  219000.0  269500.0  210000.0
# 2020-07-08  326030  SK바이오팜  217000.0    500.0  214500.0  225000.0  198000.0
#
#                    거래량
# 날짜
# 2020-07-02    698642.0
# 2020-07-03    711921.0
# 2020-07-06   7126211.0
# 2020-07-07  10105187.0
# 2020-07-08   5990009.0

# %%
df.head()
# Out:
#               종목코드     종목명        종가      전일비        시가        고가        저가  \
# 날짜
# 2020-07-02  326030  SK바이오팜  127000.0  29000.0   98000.0  127000.0   98000.0
# 2020-07-03  326030  SK바이오팜  165000.0  38000.0  165000.0  165000.0  165000.0
# 2020-07-06  326030  SK바이오팜  214500.0  49500.0  214500.0  214500.0  193500.0
# 2020-07-07  326030  SK바이오팜  216500.0   2000.0  219000.0  269500.0  210000.0
# 2020-07-08  326030  SK바이오팜  217000.0    500.0  214500.0  225000.0  198000.0
#
#                    거래량
# 날짜
# 2020-07-02    698642.0
# 2020-07-03    711921.0
# 2020-07-06   7126211.0
# 2020-07-07  10105187.0
# 2020-07-08   5990009.0

# %%
df.columns = ['종목코드', '종목명', 'Close', '전일비', 'Open', 'High', 'Low', 'Volume']

# %%
import mplfinance as mpf
mpf.plot(df)

# %%
mpf.plot(df,type='candle')

# %%
mpf.plot(df,type='ohlc',mav=4)

# %%
mpf.plot(df,type='candle',mav=(3,6,9),volume=True)
